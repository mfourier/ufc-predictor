# %% [markdown]
# # 🔹Exploratory Data Analysis

# %% [markdown]
# ## 1. Import Libraries and Setup Environment

# %%
# Import necessary libraries
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the project root directory
project_root = '/home/mfourier/Documentos/ufc_predictor'
sys.path.append(os.path.join(project_root, 'data/random'))
import random_data

# %% [markdown]
# ## 2. Load Data

# %%
# Load data
df_train, df_test = random_data.random_ufc_data()

# Separate training and testing sets
X_train = df_train.iloc[:, :-1]  # Todas las columnas excepto la última
y_train = df_train.iloc[:, -1]   # Solo la última columna

X_test = df_test.iloc[:, :-1]
y_test = df_test.iloc[:, -1]

# %% [markdown]
# ## 3.  Initial Data Exploration

# %%
# View the first few rows of the training data
df_train.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  -1.111103   0.057607   1.265346  -0.789818  -0.811185  -1.063960
# 1   1.761051   1.190423  -0.820491  -0.948589   0.441731  -0.832844
# 2  -0.433107   0.914340  -0.434065  -2.423948  -0.323394  -0.238422
# 3   0.294473  -1.214849  -0.094670   1.145139   1.250101  -1.042882
# 4   1.949312  -1.196688  -0.261813   0.887320   0.545849   1.452920
#
#    feature_7  feature_8  feature_9  feature_10  winner
# 0  -0.296031  -0.300221   1.408817   -1.883275       0
# 1  -1.131557   0.157000   1.108804    0.452083       0
# 2   0.945678   1.159685  -0.463750    0.116661       1
# 3   0.453353   0.798746   0.281390   -0.769426       0
# 4  -1.301120   1.147041   0.690999   -1.799953       0

# %%
# Descriptive statistics
df_train.describe()
# Out:
#           feature_1     feature_2     feature_3     feature_4     feature_5  \
# count  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02
# mean   1.776357e-17 -5.773160e-17 -1.776357e-17 -2.220446e-17 -3.552714e-17
# std    1.000626e+00  1.000626e+00  1.000626e+00  1.000626e+00  1.000626e+00
# min   -2.252759e+00 -2.318710e+00 -2.293475e+00 -2.423948e+00 -2.284739e+00
# 25%   -7.024851e-01 -7.103154e-01 -7.057610e-01 -7.416366e-01 -7.042116e-01
# 50%   -1.897930e-03  1.979685e-02  1.024580e-02 -1.745019e-03 -2.263448e-02
# 75%    6.847869e-01  7.037375e-01  7.328684e-01  7.277479e-01  6.750359e-01
# max    2.268000e+00  2.260228e+00  2.245002e+00  2.436127e+00  2.379907e+00
#
#           feature_6     feature_7     feature_8     feature_9    feature_10  \
# count  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02  8.000000e+02
# mean  -3.996803e-17 -5.995204e-17  2.664535e-17  6.217249e-17  2.886580e-17
# std    1.000626e+00  1.000626e+00  1.000626e+00  1.000626e+00  1.000626e+00
# min   -2.226429e+00 -2.419639e+00 -2.219482e+00 -2.262682e+00 -2.320197e+00
# 25%   -7.088026e-01 -7.040365e-01 -7.762526e-01 -7.480824e-01 -6.496247e-01
# 50%   -6.027904e-03 -1.103221e-02  5.357005e-02 -1.008095e-02 -6.988535e-03
# 75%    7.360159e-01  6.989766e-01  7.299181e-01  7.082228e-01  7.293388e-01
# max    2.375195e+00  2.403554e+00  2.313400e+00  2.348619e+00  2.402310e+00
#
#            winner
# count  800.000000
# mean     0.526250
# std      0.499623
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
# DataFrame information
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   feature_1   800 non-null    float64
#  1   feature_2   800 non-null    float64
#  2   feature_3   800 non-null    float64
#  3   feature_4   800 non-null    float64
#  4   feature_5   800 non-null    float64
#  5   feature_6   800 non-null    float64
#  6   feature_7   800 non-null    float64
#  7   feature_8   800 non-null    float64
#  8   feature_9   800 non-null    float64
#  9   feature_10  800 non-null    float64
#  10  winner      800 non-null    int64
# dtypes: float64(10), int64(1)
# memory usage: 68.9 KB

# %% [markdown]
# ## 4. Target Variable Exploration

# %% [markdown]
# ### Visualizing the Distribution of the Target Variable

# %%
# Distribution of the target variable (assuming it's binary)
sns.countplot(x=y_train)
plt.title("Distribution of Target Variable")
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 5. Univariate Analysis of Features (X)

# %%
# Histograms of the predictor features
X_train.hist(bins=15, figsize=(15, 10))
plt.suptitle("Distribution of Predictor Features")
plt.show()

# %% [markdown]
# ## 6. Correlation Between Features

# %%
# Correlation between features
correlation_matrix = X_train.corr()

# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 7. Relationships Between Features and Target Variable

# %%
# Relationship between features and target variable
for col in X_train.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=y_train, y=X_train[col])
    plt.title(f"Relationship Between {col} and Target Variable")
    plt.xlabel("Class")
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# ## 8. Outliers Analysis

# %%
# Boxplots to detect outliers
for col in X_train.columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(X_train[col])
    plt.title(f"Outlier Detection for {col}")
    plt.show()
