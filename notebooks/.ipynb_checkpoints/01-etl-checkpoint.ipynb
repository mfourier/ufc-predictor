# %% [markdown]
# # 🔹UFC Fight Predictor ETL

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 1. Import Libraries and Setup Environment

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root, 'src'))
from helpers import *

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 2. Load Data

# %%
# Define the path to the CSV file
file_path = os.path.join(project_root, 'data', 'raw', 'ufc_raw.csv')

# Load the CSV into a DataFrame
try:
    ufc_raw = pd.read_csv(file_path)
    print_header(f"Data successfully loaded: {ufc_raw.shape[0]} rows, {ufc_raw.shape[1]} columns.", color='bright_green')
except Exception as e:
    print_header(f"Error loading training data: {e}", color='bright_red')
# Out:
# ╔═════════════════════════════════════════════════════╗
# ║  Data successfully loaded: 6541 rows, 118 columns.  ║
# ╚═════════════════════════════════════════════════════╝

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 3. Preview

# %%
# Preview the first few records
display(ufc_raw.head())

# General dataset information
ufc_raw.info()
# Out:
#         RedFighter        BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Colby Covington    Joaquin Buckley    205.0    -250.0          205.0000
# 1      Cub Swanson  Billy Quarantillo    124.0    -148.0          124.0000
# 2       Manel Kape        Bruno Silva   -395.0     310.0           25.3165
# 3    Vitor Petrino      Dustin Jacoby   -340.0     270.0           29.4118
# 4     Adrian Yanez      Daniel Marcos    185.0    -225.0          185.0000
#
#    BlueExpectedValue        Date             Location Country Winner  ...  \
# 0            40.0000  2024-12-14  Tampa, Florida, USA     USA   Blue  ...
# 1            67.5676  2024-12-14  Tampa, Florida, USA     USA    Red  ...
# 2           310.0000  2024-12-14  Tampa, Florida, USA     USA    Red  ...
# 3           270.0000  2024-12-14  Tampa, Florida, USA     USA   Blue  ...
# 4            44.4444  2024-12-14  Tampa, Florida, USA     USA   Blue  ...
#
#    FinishDetails FinishRound FinishRoundTime  TotalFightTimeSecs  RedDecOdds  \
# 0            NaN         3.0            4:42               882.0       300.0
# 1          Punch         3.0            1:36               696.0       250.0
# 2        Punches         3.0            1:57               717.0      -105.0
# 3          Punch         3.0            3:44               824.0       240.0
# 4            NaN         3.0            5:00               900.0       450.0
#
#    BlueDecOdds  RSubOdds  BSubOdds  RKOOdds  BKOOdds
# 0        175.0    1800.0    2000.0   1100.0    150.0
# 1          NaN    1800.0       NaN    450.0      NaN
# 2        550.0     900.0    1800.0    225.0   1100.0
# 3        500.0     550.0    3000.0    110.0    800.0
# 4        150.0    2200.0    2200.0    450.0    200.0
#
# [5 rows x 118 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6541 entries, 0 to 6540
# Columns: 118 entries, RedFighter to BKOOdds
# dtypes: bool(1), float64(60), int64(43), object(14)
# memory usage: 5.8+ MB

# %%
ufc_raw = ufc_raw.drop(['RedFighter','BlueFighter','RedExpectedValue', 'Finish',
                        'BlueExpectedValue','Date','Location','Country','EmptyArena',
                        'FinishDetails','FinishRound','FinishRoundTime','RedDecOdds',
                        'TotalFightTimeSecs', 'BlueDecOdds', 'RSubOdds',
                        'BSubOdds','RKOOdds','BKOOdds','WeightClass'],axis=1)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 4. Check

# %%
# Null values check
nulls = ufc_raw.isnull().sum()
print("\nNull values per column:\n", nulls[nulls > 0])

# Duplicate analysis
duplicates = ufc_raw.duplicated().sum()
print(f"\nDuplicate rows: {duplicates}")
# Out:
# Null values per column:
#  RedOdds                   227
# BlueOdds                  226
# BlueAvgSigStrLanded       930
# BlueAvgSigStrPct          765
# BlueAvgSubAtt             832
# BlueAvgTDLanded           833
# BlueAvgTDPct              842
# BlueStance                  3
# RedAvgSigStrLanded        455
# RedAvgSigStrPct           357
# RedAvgSubAtt              357
# RedAvgTDLanded            357
# RedAvgTDPct               367
# BMatchWCRank             5339
# RMatchWCRank             4760
# RWFlyweightRank          6445
# RWFeatherweightRank      6532
# RWStrawweightRank        6395
# RWBantamweightRank       6387
# RHeavyweightRank         6355
# RLightHeavyweightRank    6357
# RMiddleweightRank        6359
# RWelterweightRank        6349
# RLightweightRank         6357
# RFeatherweightRank       6364
# RBantamweightRank        6360
# RFlyweightRank           6352
# RPFPRank                 6288
# BWFlyweightRank          6468
# BWFeatherweightRank      6540
# BWStrawweightRank        6441
# BWBantamweightRank       6434
# BHeavyweightRank         6393
# BLightHeavyweightRank    6421
# BMiddleweightRank        6404
# BWelterweightRank        6421
# BLightweightRank         6421
# BFeatherweightRank       6417
# BBantamweightRank        6422
# BFlyweightRank           6410
# BPFPRank                 6474
# dtype: int64
#
# Duplicate rows: 0

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 5. Data Cleaning

# %% [markdown]
# ### Null Values

# %%
# Drop columns with too many null values (threshold: 300)
threshold = 931
cols_to_drop = [col for col in ufc_raw.columns if ufc_raw[col].isnull().sum() > threshold]
for col in cols_to_drop:
    print('Dropping:', col)
ufc_raw.drop(columns=cols_to_drop, inplace=True)

# Drop rows with any remaining missing values
print(f"➡️ Before dropna: {ufc_raw.shape}")
ufc_raw.dropna(inplace=True)
print(f"✅ After dropna: {ufc_raw.shape}")
# Out:
# Dropping: BMatchWCRank
# Dropping: RMatchWCRank
# Dropping: RWFlyweightRank
# Dropping: RWFeatherweightRank
# Dropping: RWStrawweightRank
# Dropping: RWBantamweightRank
# Dropping: RHeavyweightRank
# Dropping: RLightHeavyweightRank
# Dropping: RMiddleweightRank
# Dropping: RWelterweightRank
# Dropping: RLightweightRank
# Dropping: RFeatherweightRank
# Dropping: RBantamweightRank
# Dropping: RFlyweightRank
# Dropping: RPFPRank
# Dropping: BWFlyweightRank
# Dropping: BWFeatherweightRank
# Dropping: BWStrawweightRank
# Dropping: BWBantamweightRank
# Dropping: BHeavyweightRank
# Dropping: BLightHeavyweightRank
# Dropping: BMiddleweightRank
# Dropping: BWelterweightRank
# Dropping: BLightweightRank
# Dropping: BFeatherweightRank
# Dropping: BBantamweightRank
# Dropping: BFlyweightRank
# Dropping: BPFPRank
# ➡️ Before dropna: (6541, 70)
# ✅ After dropna: (5259, 70)

# %%
# Null values check
nulls = ufc_raw.isnull().sum()
print("\nNull values per column:\n", nulls[nulls > 0])
# Out:
# Null values per column:
#  Series([], dtype: int64)

# %% [markdown]
# ### Incongruent Data

# %%
print(ufc_raw[['RedReachCms', 'BlueReachCms']].describe())
# Out:
#        RedReachCms  BlueReachCms
# count  5259.000000   5259.000000
# mean    182.630681    182.436187
# std      11.155970     11.195879
# min     147.320000      0.000000
# 25%     175.260000    175.260000
# 50%     182.880000    182.880000
# 75%     190.500000    190.500000
# max     213.360000    213.360000

# %%
# Reemplazar ceros o nulos en los alcances antes de dividir
ufc_raw['RedReachCms'] = ufc_raw['RedReachCms'].replace(0, ufc_raw['RedReachCms'].mean())
ufc_raw['BlueReachCms'] = ufc_raw['BlueReachCms'].replace(0, ufc_raw['BlueReachCms'].mean())

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 6. Preview Clean Data

# %%
# Preview the first few records
display(ufc_raw.head())

# General dataset information
ufc_raw.info()
# Out:
#    RedOdds  BlueOdds Winner  TitleBout Gender  NumberOfRounds  \
# 0    205.0    -250.0   Blue      False   MALE               5
# 1    124.0    -148.0    Red      False   MALE               3
# 2   -395.0     310.0    Red      False   MALE               3
# 3   -340.0     270.0   Blue      False   MALE               3
# 4    185.0    -225.0   Blue      False   MALE               3
#
#    BlueCurrentLoseStreak  BlueCurrentWinStreak  BlueDraws  \
# 0                      0                     5          0
# 1                      1                     0          0
# 2                      0                     4          0
# 3                      2                     0          1
# 4                      0                     4          0
#
#    BlueAvgSigStrLanded  ...  TotalTitleBoutDif  KODif  SubDif  HeightDif  \
# 0                 4.13  ...                 -4      4      -2      -2.54
# 1                 7.36  ...                  0     -2      -1       5.08
# 2                 3.32  ...                  0      1       1      -2.54
# 3                 5.50  ...                  0      2      -1       2.54
# 4                 5.94  ...                  0     -5       0       0.00
#
#    ReachDif  AgeDif  SigStrDif  AvgSubAttDif  AvgTDDif  BetterRank
# 0     10.16      -6       0.25          -0.2     -1.83         Red
# 1      0.00      -5       2.69           0.7      0.20     neither
# 2     -7.62       3      -1.12          -0.2      1.72         Red
# 3     -2.54       9       2.68          -0.8     -3.62     neither
# 4     -2.54       0      -0.57           0.0      0.25     neither
#
# [5 rows x 70 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 5259 entries, 0 to 6540
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   RedOdds                      5259 non-null   float64
#  1   BlueOdds                     5259 non-null   float64
#  2   Winner                       5259 non-null   object
#  3   TitleBout                    5259 non-null   bool
#  4   Gender                       5259 non-null   object
#  5   NumberOfRounds               5259 non-null   int64
#  6   BlueCurrentLoseStreak        5259 non-null   int64
#  7   BlueCurrentWinStreak         5259 non-null   int64
#  8   BlueDraws                    5259 non-null   int64
#  9   BlueAvgSigStrLanded          5259 non-null   float64
#  10  BlueAvgSigStrPct             5259 non-null   float64
#  11  BlueAvgSubAtt                5259 non-null   float64
#  12  BlueAvgTDLanded              5259 non-null   float64
#  13  BlueAvgTDPct                 5259 non-null   float64
#  14  BlueLongestWinStreak         5259 non-null   int64
#  15  BlueLosses                   5259 non-null   int64
#  16  BlueTotalRoundsFought        5259 non-null   int64
#  17  BlueTotalTitleBouts          5259 non-null   int64
#  18  BlueWinsByDecisionMajority   5259 non-null   int64
#  19  BlueWinsByDecisionSplit      5259 non-null   int64
#  20  BlueWinsByDecisionUnanimous  5259 non-null   int64
#  21  BlueWinsByKO                 5259 non-null   int64
#  22  BlueWinsBySubmission         5259 non-null   int64
#  23  BlueWinsByTKODoctorStoppage  5259 non-null   int64
#  24  BlueWins                     5259 non-null   int64
#  25  BlueStance                   5259 non-null   object
#  26  BlueHeightCms                5259 non-null   float64
#  27  BlueReachCms                 5259 non-null   float64
#  28  BlueWeightLbs                5259 non-null   int64
#  29  RedCurrentLoseStreak         5259 non-null   int64
#  30  RedCurrentWinStreak          5259 non-null   int64
#  31  RedDraws                     5259 non-null   int64
#  32  RedAvgSigStrLanded           5259 non-null   float64
#  33  RedAvgSigStrPct              5259 non-null   float64
#  34  RedAvgSubAtt                 5259 non-null   float64
#  35  RedAvgTDLanded               5259 non-null   float64
#  36  RedAvgTDPct                  5259 non-null   float64
#  37  RedLongestWinStreak          5259 non-null   int64
#  38  RedLosses                    5259 non-null   int64
#  39  RedTotalRoundsFought         5259 non-null   int64
#  40  RedTotalTitleBouts           5259 non-null   int64
#  41  RedWinsByDecisionMajority    5259 non-null   int64
#  42  RedWinsByDecisionSplit       5259 non-null   int64
#  43  RedWinsByDecisionUnanimous   5259 non-null   int64
#  44  RedWinsByKO                  5259 non-null   int64
#  45  RedWinsBySubmission          5259 non-null   int64
#  46  RedWinsByTKODoctorStoppage   5259 non-null   int64
#  47  RedWins                      5259 non-null   int64
#  48  RedStance                    5259 non-null   object
#  49  RedHeightCms                 5259 non-null   float64
#  50  RedReachCms                  5259 non-null   float64
#  51  RedWeightLbs                 5259 non-null   int64
#  52  RedAge                       5259 non-null   int64
#  53  BlueAge                      5259 non-null   int64
#  54  LoseStreakDif                5259 non-null   int64
#  55  WinStreakDif                 5259 non-null   int64
#  56  LongestWinStreakDif          5259 non-null   int64
#  57  WinDif                       5259 non-null   int64
#  58  LossDif                      5259 non-null   int64
#  59  TotalRoundDif                5259 non-null   int64
#  60  TotalTitleBoutDif            5259 non-null   int64
#  61  KODif                        5259 non-null   int64
#  62  SubDif                       5259 non-null   int64
#  63  HeightDif                    5259 non-null   float64
#  64  ReachDif                     5259 non-null   float64
#  65  AgeDif                       5259 non-null   int64
#  66  SigStrDif                    5259 non-null   float64
#  67  AvgSubAttDif                 5259 non-null   float64
#  68  AvgTDDif                     5259 non-null   float64
#  69  BetterRank                   5259 non-null   object
# dtypes: bool(1), float64(21), int64(43), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 7. Check Clean Data

# %%
# Null values check
nulls = ufc_raw.isnull().sum()
print("\nNull values per column:\n", nulls[nulls > 0])

# Duplicate analysis
duplicates = ufc_raw.duplicated().sum()
print(f"\nDuplicate rows: {duplicates}")
# Out:
# Null values per column:
#  Series([], dtype: int64)
#
# Duplicate rows: 0

# %%
# Preview the first few records
display(ufc_raw.head())
display(ufc_raw.columns)
# Para ver los tipos de dato de cada columna:
display(ufc_raw.dtypes)
# Out:
#    RedOdds  BlueOdds Winner  TitleBout Gender  NumberOfRounds  \
# 0    205.0    -250.0   Blue      False   MALE               5
# 1    124.0    -148.0    Red      False   MALE               3
# 2   -395.0     310.0    Red      False   MALE               3
# 3   -340.0     270.0   Blue      False   MALE               3
# 4    185.0    -225.0   Blue      False   MALE               3
#
#    BlueCurrentLoseStreak  BlueCurrentWinStreak  BlueDraws  \
# 0                      0                     5          0
# 1                      1                     0          0
# 2                      0                     4          0
# 3                      2                     0          1
# 4                      0                     4          0
#
#    BlueAvgSigStrLanded  ...  TotalTitleBoutDif  KODif  SubDif  HeightDif  \
# 0                 4.13  ...                 -4      4      -2      -2.54
# 1                 7.36  ...                  0     -2      -1       5.08
# 2                 3.32  ...                  0      1       1      -2.54
# 3                 5.50  ...                  0      2      -1       2.54
# 4                 5.94  ...                  0     -5       0       0.00
#
#    ReachDif  AgeDif  SigStrDif  AvgSubAttDif  AvgTDDif  BetterRank
# 0     10.16      -6       0.25          -0.2     -1.83         Red
# 1      0.00      -5       2.69           0.7      0.20     neither
# 2     -7.62       3      -1.12          -0.2      1.72         Red
# 3     -2.54       9       2.68          -0.8     -3.62     neither
# 4     -2.54       0      -0.57           0.0      0.25     neither
#
# [5 rows x 70 columns]
# Index(['RedOdds', 'BlueOdds', 'Winner', 'TitleBout', 'Gender',
#        'NumberOfRounds', 'BlueCurrentLoseStreak', 'BlueCurrentWinStreak',
#        'BlueDraws', 'BlueAvgSigStrLanded', 'BlueAvgSigStrPct', 'BlueAvgSubAtt',
#        'BlueAvgTDLanded', 'BlueAvgTDPct', 'BlueLongestWinStreak', 'BlueLosses',
#        'BlueTotalRoundsFought', 'BlueTotalTitleBouts',
#        'BlueWinsByDecisionMajority', 'BlueWinsByDecisionSplit',
#        'BlueWinsByDecisionUnanimous', 'BlueWinsByKO', 'BlueWinsBySubmission',
#        'BlueWinsByTKODoctorStoppage', 'BlueWins', 'BlueStance',
#        'BlueHeightCms', 'BlueReachCms', 'BlueWeightLbs',
#        'RedCurrentLoseStreak', 'RedCurrentWinStreak', 'RedDraws',
#        'RedAvgSigStrLanded', 'RedAvgSigStrPct', 'RedAvgSubAtt',
#        'RedAvgTDLanded', 'RedAvgTDPct', 'RedLongestWinStreak', 'RedLosses',
#        'RedTotalRoundsFought', 'RedTotalTitleBouts',
#        'RedWinsByDecisionMajority', 'RedWinsByDecisionSplit',
#        'RedWinsByDecisionUnanimous', 'RedWinsByKO', 'RedWinsBySubmission',
#        'RedWinsByTKODoctorStoppage', 'RedWins', 'RedStance', 'RedHeightCms',
#        'RedReachCms', 'RedWeightLbs', 'RedAge', 'BlueAge', 'LoseStreakDif',
#        'WinStreakDif', 'LongestWinStreakDif', 'WinDif', 'LossDif',
#        'TotalRoundDif', 'TotalTitleBoutDif', 'KODif', 'SubDif', 'HeightDif',
#        'ReachDif', 'AgeDif', 'SigStrDif', 'AvgSubAttDif', 'AvgTDDif',
#        'BetterRank'],
#       dtype='object')
# RedOdds         float64
# BlueOdds        float64
# Winner           object
# TitleBout          bool
# Gender           object
#                  ...
# AgeDif            int64
# SigStrDif       float64
# AvgSubAttDif    float64
# AvgTDDif        float64
# BetterRank       object
# Length: 70, dtype: object

# %% [markdown]
# ## 8. Create the target value: **0** (Fighter Red wins) or **1** (Fighter Blue wins)

# %%
ufc_raw['label'] = ufc_raw['Winner'].apply(lambda x: 1 if x == 'Blue' else 0)
ufc_raw=ufc_raw.drop('Winner', axis=1)

# %% [markdown]
# ## 6. Save

# %%
# Save the cleaned file
ufc_raw.to_csv(f'{project_root}/data/processed/ufc_etl.csv', index=False)
print_header("ETL file saved as 'ufc_etl.csv'.", color = 'bright_green')
# Out:
# ╔════════════════════════════════════╗
# ║  ETL file saved as 'ufc_etl.csv'.  ║
# ╚════════════════════════════════════╝

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
