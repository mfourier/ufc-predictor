# %% [markdown]
# # 🔹UFC Fight Predictor Feature Engineering

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 1. Import Libraries and Setup Environment

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root, 'src'))
from helpers import *
from io_model import *
from data import UFCData

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 2. Load Data

# %%
# Define the path to the CSV file
file_path = os.path.join(project_root, 'data', 'processed', 'ufc_etl.csv')

# Load the CSV into a DataFrame
try:
    ufc_df = pd.read_csv(file_path)
    print_header(f"Data loaded succesfully", color='bright_green')
except Exception as e:
    print_header(f"Error loading data: {e}", color='bright_red')
# Out:
# ╔═══════════════════════════╗
# ║  Data loaded succesfully  ║
# ╚═══════════════════════════╝

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 3. Initialize UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6300
# 🧪 Train/Test split  : 5040 / 1260
# 🧪 Total features     : 58
#
# 🔢 Numerical features : 54
# 🔠 Categorical features: 4
#     - Binary          : 2
#     - Multiclass      : 2
#
# 🏷 Label distribution (raw):
#    - Class 0: 3662 (58.1%)
#    - Class 1: 2638 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std      min       max
# RedOdds                     -115.702  279.516 -2100.00   775.000
# BlueOdds                      59.744  253.515 -1200.00  1300.000
# NumberOfRounds                 3.193    0.588     3.00     5.000
# BlueCurrentLoseStreak          0.494    0.789     0.00     6.000
# BlueCurrentWinStreak           0.968    1.427     0.00    12.000
# BlueDraws                      0.020    0.143     0.00     2.000
# BlueLongestWinStreak           1.922    1.961     0.00    17.000
# BlueLosses                     1.842    2.154     0.00    16.000
# BlueTotalRoundsFought         11.781   13.779     0.00   111.000
# BlueTotalTitleBouts            0.244    1.038     0.00    14.000
# BlueWinsByDecisionMajority     0.016    0.127     0.00     2.000
# BlueWinsByDecisionSplit        0.278    0.593     0.00     5.000
# BlueWinsByDecisionUnanimous    1.094    1.619     0.00    11.000
# BlueWinsByKO                   1.077    1.728     0.00    20.000
# BlueWinsBySubmission           0.608    1.219     0.00    11.000
# BlueWinsByTKODoctorStoppage    0.023    0.157     0.00     2.000
# BlueWins                       3.136    3.702     0.00    31.000
# BlueHeightCms                177.817    9.139   152.40   210.820
# BlueReachCms                 182.203   10.987   147.32   213.360
# BlueWeightLbs                163.238   34.508   115.00   265.000
# RedCurrentLoseStreak           0.617    0.861     0.00     7.000
# RedCurrentWinStreak            1.110    1.773     0.00    18.000
# RedDraws                       0.030    0.186     0.00     2.000
# RedLongestWinStreak            2.685    2.250     0.00    18.000
# RedLosses                      2.552    2.676     0.00    20.000
# RedTotalRoundsFought          17.380   17.991     0.00   448.000
# RedTotalTitleBouts             0.552    1.541     0.00    16.000
# RedWinsByDecisionMajority      0.026    0.162     0.00     2.000
# RedWinsByDecisionSplit         0.398    0.692     0.00     5.000
# RedWinsByDecisionUnanimous     1.614    1.986     0.00    11.000
# RedWinsByKO                    1.574    2.156     0.00    21.000
# RedWinsBySubmission            0.930    1.609     0.00    16.000
# RedWinsByTKODoctorStoppage     0.038    0.206     0.00     2.000
# RedWins                        4.632    4.508     0.00    33.000
# RedHeightCms                 177.859    9.154   152.40   210.820
# RedReachCms                  182.429   11.085   147.32   214.630
# RedWeightLbs                 163.721   34.839   115.00   265.000
# RedAge                        30.351    4.199    18.00    47.000
# BlueAge                       29.764    3.949    19.00    45.000
# LoseStreakDif                  0.068    1.012    -6.00     6.000
# WinStreakDif                  -0.142    1.887   -18.00    10.000
# LongestWinStreakDif           -0.763    2.026   -12.00    14.000
# WinDif                        -1.496    4.167   -28.00    23.000
# LossDif                        0.102    3.103   -19.00    16.000
# TotalRoundDif                 -5.599   18.083  -448.00    87.000
# TotalTitleBoutDif             -0.308    1.663   -16.00    14.000
# KODif                         -0.512    2.140   -21.00    14.000
# SubDif                        -0.322    1.831   -16.00    10.000
# HeightDif                     -0.076    6.864  -187.96    27.940
# ReachDif                      -0.327    9.381  -187.96    30.480
# AgeDif                         0.116    5.208   -16.00    17.000
# SigStrDif                     -2.865   19.979  -118.00   128.222
# AvgSubAttDif                  -0.074    0.876    -8.30     5.667
# AvgTDDif                      -0.158    1.745   -11.00    10.860
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 4. Feature Engineering

# %% [markdown]
# ### Categorical Data

# %% [markdown]
# ### Stance
# - **Orthodox Stance:** A fighter in orthodox stance leads with their left foot and left hand, making it the natural stance for right-handed individuals.
# - **Southpaw Stance:** A fighter in southpaw stance leads with their right foot and right hand, making it the natural stance for left-handed individuals.
# - **Open Stance Matchup:** When one fighter is orthodox and the other is southpaw, it creates an "open stance" matchup. This differs from a "closed stance" where both fighters are in the same stance (e.g., both orthodox or both southpaw)
# - **Switch:** When a fighter switches from an orthodox to a southpaw stance or vice versa, it can disrupt their opponent's rhythm, causing them to miss or react incorrectly to strikes.

# %% [markdown]
# ### Feature Construction

# %%
# Finish Rate (Red & Blue):
RedFinishRate = (ufc_df['RedWinsByKO'] + ufc_df['RedWinsBySubmission'] + ufc_df['RedWinsByTKODoctorStoppage']) / ufc_df['RedWins'].replace(0, 1)
BlueFinishRate = (ufc_df['BlueWinsByKO'] + ufc_df['BlueWinsBySubmission'] + ufc_df['BlueWinsByTKODoctorStoppage']) / ufc_df['BlueWins'].replace(0, 1)
ufc_df['FinishRateDif'] = BlueFinishRate - RedFinishRate

# %%
#Win Ratio (Red & Blue)
RedWinRatio = ufc_df['RedWins'] / (ufc_df['RedWins'] + ufc_df['RedLosses']).replace(0, 1)
BlueWinRatio = ufc_df['BlueWins'] / (ufc_df['BlueWins'] + ufc_df['BlueLosses']).replace(0, 1)
ufc_df['WinRatioDif']= BlueWinRatio - RedWinRatio

# %%
# Experience per Age
RedExpPerAge = ufc_df['RedTotalRoundsFought'] / ufc_df['RedAge']
BlueExpPerAge = ufc_df['BlueTotalRoundsFought'] / ufc_df['BlueAge']
ufc_df['ExpPerAgeDif'] = BlueExpPerAge - RedExpPerAge

# %%
# Reach Advantage Ratio
ufc_df['ReachAdvantageRatioDif'] = ufc_df['BlueReachCms'] / ufc_df['RedReachCms']

# %%
# Height/Reach Ratio
RedHeightReachRatio = ufc_df['RedHeightCms'] / ufc_df['RedReachCms']
BlueHeightReachRatio = ufc_df['BlueHeightCms'] / ufc_df['BlueReachCms']
ufc_df['HeightReachRatioDif']= BlueHeightReachRatio - RedHeightReachRatio

# %%
# Win By Decision
BlueWinsByDecision = ufc_df[['BlueWinsByDecisionMajority', 'BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous']].sum(axis=1)
RedWinsByDecision = ufc_df[['RedWinsByDecisionMajority', 'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous']].sum(axis=1)
ufc_df['WinsByDecisionDif']=BlueWinsByDecision- RedWinsByDecision

# %%
# Decision Rate
BlueDecisionRate = BlueWinsByDecision / ufc_df['BlueWins'].replace(0, 1)  # Evitar división por cero
RedDecisionRate = RedWinsByDecision  / ufc_df['RedWins'].replace(0, 1)  # Evitar división por cero
ufc_df['DecisionRateDif']= BlueDecisionRate - RedDecisionRate

# %%
# Odds Dif
ufc_df['OddsDif'] = ufc_df['BlueOdds'] - ufc_df['RedOdds']

# %%
# # AvgSigStrLandedDif
# ufc_df['AvgSigStrLandedDif'] = ufc_df['BlueAvgSigStrLanded'] - ufc_df['RedAvgSigStrLanded']

# %%
# # AvgSigStrPctDif
# ufc_df['AvgSigStrPctDif'] = ufc_df['BlueAvgSigStrPct'] - ufc_df['RedAvgSigStrPct']

# %%
# # AvgSubAttDif
# ufc_df['AvgSubAttDif'] = ufc_df['BlueAvgSubAtt'] - ufc_df['RedAvgSubAtt']

# %%
# # AvgTDLandedDif
# ufc_df['AvgTDLandedDif'] = ufc_df['BlueAvgTDLanded'] - ufc_df['RedAvgTDLanded']

# %%
# # AvgTDPctDif
# ufc_df['AvgTDPctDif'] = ufc_df['BlueAvgTDPct'] - ufc_df['RedAvgTDPct']

# %% [markdown]
# ## 5. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6300
# 🧪 Train/Test split  : 5040 / 1260
# 🧪 Total features     : 66
#
# 🔢 Numerical features : 62
# 🔠 Categorical features: 4
#     - Binary          : 2
#     - Multiclass      : 2
#
# 🏷 Label distribution (raw):
#    - Class 0: 3662 (58.1%)
#    - Class 1: 2638 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std       min       max
# RedOdds                     -115.702  279.516 -2100.000   775.000
# BlueOdds                      59.744  253.515 -1200.000  1300.000
# NumberOfRounds                 3.193    0.588     3.000     5.000
# BlueCurrentLoseStreak          0.494    0.789     0.000     6.000
# BlueCurrentWinStreak           0.968    1.427     0.000    12.000
# BlueDraws                      0.020    0.143     0.000     2.000
# BlueLongestWinStreak           1.922    1.961     0.000    17.000
# BlueLosses                     1.842    2.154     0.000    16.000
# BlueTotalRoundsFought         11.781   13.779     0.000   111.000
# BlueTotalTitleBouts            0.244    1.038     0.000    14.000
# BlueWinsByDecisionMajority     0.016    0.127     0.000     2.000
# BlueWinsByDecisionSplit        0.278    0.593     0.000     5.000
# BlueWinsByDecisionUnanimous    1.094    1.619     0.000    11.000
# BlueWinsByKO                   1.077    1.728     0.000    20.000
# BlueWinsBySubmission           0.608    1.219     0.000    11.000
# BlueWinsByTKODoctorStoppage    0.023    0.157     0.000     2.000
# BlueWins                       3.136    3.702     0.000    31.000
# BlueHeightCms                177.817    9.139   152.400   210.820
# BlueReachCms                 182.203   10.987   147.320   213.360
# BlueWeightLbs                163.238   34.508   115.000   265.000
# RedCurrentLoseStreak           0.617    0.861     0.000     7.000
# RedCurrentWinStreak            1.110    1.773     0.000    18.000
# RedDraws                       0.030    0.186     0.000     2.000
# RedLongestWinStreak            2.685    2.250     0.000    18.000
# RedLosses                      2.552    2.676     0.000    20.000
# RedTotalRoundsFought          17.380   17.991     0.000   448.000
# RedTotalTitleBouts             0.552    1.541     0.000    16.000
# RedWinsByDecisionMajority      0.026    0.162     0.000     2.000
# RedWinsByDecisionSplit         0.398    0.692     0.000     5.000
# RedWinsByDecisionUnanimous     1.614    1.986     0.000    11.000
# RedWinsByKO                    1.574    2.156     0.000    21.000
# RedWinsBySubmission            0.930    1.609     0.000    16.000
# RedWinsByTKODoctorStoppage     0.038    0.206     0.000     2.000
# RedWins                        4.632    4.508     0.000    33.000
# RedHeightCms                 177.859    9.154   152.400   210.820
# RedReachCms                  182.429   11.085   147.320   214.630
# RedWeightLbs                 163.721   34.839   115.000   265.000
# RedAge                        30.351    4.199    18.000    47.000
# BlueAge                       29.764    3.949    19.000    45.000
# LoseStreakDif                  0.068    1.012    -6.000     6.000
# WinStreakDif                  -0.142    1.887   -18.000    10.000
# LongestWinStreakDif           -0.763    2.026   -12.000    14.000
# WinDif                        -1.496    4.167   -28.000    23.000
# LossDif                        0.102    3.103   -19.000    16.000
# TotalRoundDif                 -5.599   18.083  -448.000    87.000
# TotalTitleBoutDif             -0.308    1.663   -16.000    14.000
# KODif                         -0.512    2.140   -21.000    14.000
# SubDif                        -0.322    1.831   -16.000    10.000
# HeightDif                     -0.076    6.864  -187.960    27.940
# ReachDif                      -0.327    9.381  -187.960    30.480
# AgeDif                         0.116    5.208   -16.000    17.000
# SigStrDif                     -2.865   19.979  -118.000   128.222
# AvgSubAttDif                  -0.074    0.876    -8.300     5.667
# AvgTDDif                      -0.158    1.745   -11.000    10.860
# FinishRateDif                 -0.081    0.476    -1.000     1.000
# WinRatioDif                   -0.100    0.361    -1.000     1.000
# ExpPerAgeDif                  -0.167    0.520   -13.176     2.133
# ReachAdvantageRatioDif         1.000    0.045     0.829     1.172
# HeightReachRatioDif            0.001    0.035    -0.120     0.124
# WinsByDecisionDif             -0.650    2.474   -14.000    11.000
# DecisionRateDif               -0.059    0.460    -1.000     1.000
# OddsDif                      175.446  528.040 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 6. Feature Selection

# %% [markdown]
# Dado lo siguiente:
# -  LoseStreakDif: BlueCurrentLoseStreak - RedCurrentLoseStreak
# -  WinStreakDif: BlueCurrentWinStreak - RedCurrentWinStreak
# -  LongestWinStreakDif: BlueLongestWinStreak - 'RedLongestWinStreak
# -  WinDif: BlueWins - RedWins
# -  LossDif: BlueLosses - RedLosses
# -  TotalTitleBoutDif: BlueTotalTitleBouts - RedTotalTitleBouts
# -  KODif: BlueWinsByKO - RedWinsByKO
# -  SubDif: BlueWinsBySubmission - RedWinsBySubmission
# -  HeightDif: BlueHeightCms - RedHeightCms
# -  ReachDif: BlueReachCms - RedReachCms
# -  AgeDif: BlueAge - RedAge
# -  Odds Dif: BlueOdds - RedOdds
# Se eliminan ciertas columnas que pueden ser redundantes.

# %%
ufc_df=ufc_df.drop(['BlueCurrentLoseStreak', 'RedCurrentLoseStreak','BlueCurrentWinStreak',
                      'RedCurrentWinStreak','BlueLongestWinStreak', 'RedLongestWinStreak', 'BlueWins',
                      'RedWins','BlueLosses','RedLosses', 'BlueTotalRoundsFought','RedTotalRoundsFought',
                      'BlueTotalTitleBouts', 'RedTotalTitleBouts', 'BlueWinsByKO', 'RedWinsByKO', 'BlueWinsBySubmission',
                      'RedWinsBySubmission','BlueHeightCms','RedHeightCms','BlueReachCms','RedReachCms',
                      'BlueAge', 'RedAge', 'BlueOdds','RedOdds'], axis=1)

# %% [markdown]
# También aquellas relacionadas con los features construidos:
# - WinsByDecisionDif
# - DecisionRateDif
# - FinishRateDif

# %%
ufc_df=ufc_df.drop(['BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous',
       'BlueWinsByTKODoctorStoppage', 'RedWinsByDecisionMajority',
       'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous',
       'RedWinsByTKODoctorStoppage','BlueWinsByDecisionMajority'], axis=1)

# %% [markdown]
# ### Low Variance columns
# - BlueDraws
# - RedDraws
# - BlueWeightLbs
# - RedWeightLbs

# %%
ufc_df = ufc_df.drop(['BlueDraws','RedDraws','BlueWeightLbs','RedWeightLbs'], axis=1)

# %% [markdown]
# ## 7. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6300
# 🧪 Train/Test split  : 5040 / 1260
# 🧪 Total features     : 28
#
# 🔢 Numerical features : 24
# 🔠 Categorical features: 4
#     - Binary          : 2
#     - Multiclass      : 2
#
# 🏷 Label distribution (raw):
#    - Class 0: 3662 (58.1%)
#    - Class 1: 2638 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                            mean      std       min       max
# NumberOfRounds            3.193    0.588     3.000     5.000
# LoseStreakDif             0.068    1.012    -6.000     6.000
# WinStreakDif             -0.142    1.887   -18.000    10.000
# LongestWinStreakDif      -0.763    2.026   -12.000    14.000
# WinDif                   -1.496    4.167   -28.000    23.000
# LossDif                   0.102    3.103   -19.000    16.000
# TotalRoundDif            -5.599   18.083  -448.000    87.000
# TotalTitleBoutDif        -0.308    1.663   -16.000    14.000
# KODif                    -0.512    2.140   -21.000    14.000
# SubDif                   -0.322    1.831   -16.000    10.000
# HeightDif                -0.076    6.864  -187.960    27.940
# ReachDif                 -0.327    9.381  -187.960    30.480
# AgeDif                    0.116    5.208   -16.000    17.000
# SigStrDif                -2.865   19.979  -118.000   128.222
# AvgSubAttDif             -0.074    0.876    -8.300     5.667
# AvgTDDif                 -0.158    1.745   -11.000    10.860
# FinishRateDif            -0.081    0.476    -1.000     1.000
# WinRatioDif              -0.100    0.361    -1.000     1.000
# ExpPerAgeDif             -0.167    0.520   -13.176     2.133
# ReachAdvantageRatioDif    1.000    0.045     0.829     1.172
# HeightReachRatioDif       0.001    0.035    -0.120     0.124
# WinsByDecisionDif        -0.650    2.474   -14.000    11.000
# DecisionRateDif          -0.059    0.460    -1.000     1.000
# OddsDif                 175.446  528.040 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 8. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                   Feature 1               Feature 2  Correlation
# 134           TotalRoundDif            ExpPerAgeDif     0.981060
# 205                ReachDif  ReachAdvantageRatioDif     0.893983
# 87                   WinDif           TotalRoundDif     0.860521
# 99                   WinDif            ExpPerAgeDif     0.841164
# 137           TotalRoundDif       WinsByDecisionDif     0.740159
# 102                  WinDif       WinsByDecisionDif     0.734128
# 263            ExpPerAgeDif       WinsByDecisionDif     0.731751
# 66      LongestWinStreakDif                  WinDif     0.664174
# 266  ReachAdvantageRatioDif     HeightReachRatioDif     0.641522
# 185               HeightDif                ReachDif     0.631015
# 89                   WinDif                   KODif     0.628292
# 193               HeightDif  ReachAdvantageRatioDif     0.587125
# 206                ReachDif     HeightReachRatioDif     0.560036
# 253           FinishRateDif         DecisionRateDif     0.534053
# 273       WinsByDecisionDif         DecisionRateDif     0.521706
# 83      LongestWinStreakDif       WinsByDecisionDif     0.514435
# 80      LongestWinStreakDif            ExpPerAgeDif     0.508162

# %%
ufc_data.plot_corr(processed = status)

# %% [markdown]
# ## 9. Redundant Column
# - Number of Rounds: Equivalent to Titlebout
# - TotalRoundDif: BlueTotalRoundsFought - RedTotalRoundsFought (better to use ExpPerAgeDif)

# %%
ufc_df = ufc_df.drop(['NumberOfRounds', 'TotalRoundDif'], axis=1)

# %%
# Preview the first few records
display(ufc_df.head())
display(ufc_df.columns)
# Out:
#    TitleBout Gender BlueStance RedStance  LoseStreakDif  WinStreakDif  \
# 0      False   MALE   Southpaw  Orthodox             -1             5
# 1      False   MALE   Orthodox  Orthodox              0             0
# 2      False   MALE   Orthodox  Southpaw             -1             4
# 3      False   MALE   Orthodox  Orthodox              1             0
# 4      False   MALE   Orthodox  Orthodox              0             3
#
#    LongestWinStreakDif  WinDif  LossDif  TotalTitleBoutDif  ...  AvgTDDif  \
# 0                   -2      -2        0                 -4  ...     -1.83
# 1                   -2     -12       -9                  0  ...      0.20
# 2                    0       0       -1                  0  ...      1.72
# 3                   -1       3        5                  0  ...     -3.62
# 4                   -2      -3       -2                  0  ...      0.25
#
#    label  FinishRateDif  WinRatioDif  ExpPerAgeDif  ReachAdvantageRatioDif  \
# 0      1       0.283333    -0.035714     -0.477778                1.055556
# 1      0       0.293233     0.042614     -1.222222                1.000000
# 2      0       0.500000     0.095238     -0.077799                0.955882
# 3      1      -0.100000    -0.261905      0.453704                0.987013
# 4      1      -0.607143     0.222222     -0.064516                0.985714
#
#    HeightReachRatioDif  WinsByDecisionDif  DecisionRateDif  OddsDif
# 0            -0.065058                 -4        -0.283333   -455.0
# 1             0.028571                 -9        -0.293233   -272.0
# 2             0.028733                 -2        -0.500000    705.0
# 3             0.025803                  2         0.100000    610.0
# 4             0.013872                  2         0.607143   -410.0
#
# [5 rows x 27 columns]
# Index(['TitleBout', 'Gender', 'BlueStance', 'RedStance', 'LoseStreakDif',
#        'WinStreakDif', 'LongestWinStreakDif', 'WinDif', 'LossDif',
#        'TotalTitleBoutDif', 'KODif', 'SubDif', 'HeightDif', 'ReachDif',
#        'AgeDif', 'SigStrDif', 'AvgSubAttDif', 'AvgTDDif', 'label',
#        'FinishRateDif', 'WinRatioDif', 'ExpPerAgeDif',
#        'ReachAdvantageRatioDif', 'HeightReachRatioDif', 'WinsByDecisionDif',
#        'DecisionRateDif', 'OddsDif'],
#       dtype='object')

# %% [markdown]
# ## 10. Update UFCData Object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6300
# 🧪 Train/Test split  : 5040 / 1260
# 🧪 Total features     : 26
#
# 🔢 Numerical features : 22
# 🔠 Categorical features: 4
#     - Binary          : 2
#     - Multiclass      : 2
#
# 🏷 Label distribution (raw):
#    - Class 0: 3662 (58.1%)
#    - Class 1: 2638 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                            mean      std       min       max
# LoseStreakDif             0.068    1.012    -6.000     6.000
# WinStreakDif             -0.142    1.887   -18.000    10.000
# LongestWinStreakDif      -0.763    2.026   -12.000    14.000
# WinDif                   -1.496    4.167   -28.000    23.000
# LossDif                   0.102    3.103   -19.000    16.000
# TotalTitleBoutDif        -0.308    1.663   -16.000    14.000
# KODif                    -0.512    2.140   -21.000    14.000
# SubDif                   -0.322    1.831   -16.000    10.000
# HeightDif                -0.076    6.864  -187.960    27.940
# ReachDif                 -0.327    9.381  -187.960    30.480
# AgeDif                    0.116    5.208   -16.000    17.000
# SigStrDif                -2.865   19.979  -118.000   128.222
# AvgSubAttDif             -0.074    0.876    -8.300     5.667
# AvgTDDif                 -0.158    1.745   -11.000    10.860
# FinishRateDif            -0.081    0.476    -1.000     1.000
# WinRatioDif              -0.100    0.361    -1.000     1.000
# ExpPerAgeDif             -0.167    0.520   -13.176     2.133
# ReachAdvantageRatioDif    1.000    0.045     0.829     1.172
# HeightReachRatioDif       0.001    0.035    -0.120     0.124
# WinsByDecisionDif        -0.650    2.474   -14.000    11.000
# DecisionRateDif          -0.059    0.460    -1.000     1.000
# OddsDif                 175.446  528.040 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 11. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                   Feature 1               Feature 2  Correlation
# 160                ReachDif  ReachAdvantageRatioDif     0.893983
# 72                   WinDif            ExpPerAgeDif     0.841164
# 75                   WinDif       WinsByDecisionDif     0.734128
# 218            ExpPerAgeDif       WinsByDecisionDif     0.731751
# 41      LongestWinStreakDif                  WinDif     0.664174
# 221  ReachAdvantageRatioDif     HeightReachRatioDif     0.641522
# 140               HeightDif                ReachDif     0.631015
# 62                   WinDif                   KODif     0.628292
# 148               HeightDif  ReachAdvantageRatioDif     0.587125
# 161                ReachDif     HeightReachRatioDif     0.560036
# 208           FinishRateDif         DecisionRateDif     0.534053
# 228       WinsByDecisionDif         DecisionRateDif     0.521706
# 57      LongestWinStreakDif       WinsByDecisionDif     0.514435
# 54      LongestWinStreakDif            ExpPerAgeDif     0.508162

# %% [markdown]
# ## 12. Inicialize Modeling Data: Standarize Numerical Data & Encode Categorical Data

# %%
ufc_data.standardize()
ufc_data.encode()

# %% [markdown]
# ## 13. Check Modeling Correlation Matrix

# %%
status = True
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                   Feature 1               Feature 2  Correlation
# 425                ReachDif  ReachAdvantageRatioDif     0.893983
# 196      RedStance_Orthodox      RedStance_Southpaw     0.848349
# 337                  WinDif            ExpPerAgeDif     0.841164
# 90      BlueStance_Orthodox     BlueStance_Southpaw     0.838789
# 340                  WinDif       WinsByDecisionDif     0.734128
# 483            ExpPerAgeDif       WinsByDecisionDif     0.731751
# 306     LongestWinStreakDif                  WinDif     0.664174
# 486  ReachAdvantageRatioDif     HeightReachRatioDif     0.641522
# 405               HeightDif                ReachDif     0.631015
# 327                  WinDif                   KODif     0.628292
# 413               HeightDif  ReachAdvantageRatioDif     0.587125
# 426                ReachDif     HeightReachRatioDif     0.560036
# 473           FinishRateDif         DecisionRateDif     0.534053
# 493       WinsByDecisionDif         DecisionRateDif     0.521706
# 322     LongestWinStreakDif       WinsByDecisionDif     0.514435
# 319     LongestWinStreakDif            ExpPerAgeDif     0.508162

# %%
ufc_data.plot_corr(processed = status, threshold = 0.6)

# %% [markdown]
# ## 14. Check Modeling Data

# %%
ufc_data._X_train_processed
# Out:
#       TitleBout  Gender_MALE  BlueStance_Open Stance  BlueStance_Orthodox  \
# 220           0            0                       0                    0
# 2052          0            1                       0                    1
# 1641          0            0                       0                    1
# 5261          0            0                       0                    1
# 3434          0            1                       0                    1
# ...         ...          ...                     ...                  ...
# 469           0            1                       0                    1
# 575           0            1                       0                    0
# 761           0            1                       0                    1
# 6159          0            1                       0                    1
# 5635          0            1                       0                    1
#
#       BlueStance_Southpaw  BlueStance_Switch  RedStance_Open Stance  \
# 220                     1                  0                      0
# 2052                    0                  0                      0
# 1641                    0                  0                      0
# 5261                    0                  0                      0
# 3434                    0                  0                      0
# ...                   ...                ...                    ...
# 469                     0                  0                      0
# 575                     1                  0                      0
# 761                     0                  0                      0
# 6159                    0                  0                      0
# 5635                    0                  0                      0
#
#       RedStance_Orthodox  RedStance_Southpaw  RedStance_Switch  ...  \
# 220                    0                   1                 0  ...
# 2052                   0                   1                 0  ...
# 1641                   1                   0                 0  ...
# 5261                   1                   0                 0  ...
# 3434                   0                   1                 0  ...
# ...                  ...                 ...               ...  ...
# 469                    1                   0                 0  ...
# 575                    1                   0                 0  ...
# 761                    0                   0                 1  ...
# 6159                   1                   0                 0  ...
# 5635                   0                   1                 0  ...
#
#       AvgSubAttDif  AvgTDDif  FinishRateDif  WinRatioDif  ExpPerAgeDif  \
# 220       0.084453 -0.098641       0.171029     0.276019      0.475248
# 2052      0.084453 -0.379440      -1.928766    -1.109916      0.000898
# 1641     -0.600412  0.950058      -1.403817    -1.109916     -0.741330
# 5261      0.084453  0.090469       0.171029     0.276019      0.405015
# 3434     -0.058227  2.669237       1.220927    -0.185960     -0.422578
# ...            ...       ...            ...          ...           ...
# 469      -0.029691 -0.230444      -0.878868    -1.109916     -1.368543
# 575       0.997606 -1.548482       0.730975    -0.070465     -0.361667
# 761       2.253190 -0.568550      -1.928766    -2.495851      0.182564
# 6159     -1.627708 -1.557078      -0.353919    -1.109916     -1.370873
# 5635     -1.564244 -1.437709      -0.528902    -1.571894     -1.459191
#
#       ReachAdvantageRatioDif  HeightReachRatioDif  WinsByDecisionDif  \
# 220                -0.644149             0.390532           0.262855
# 2052               -0.901668             1.140561           0.262855
# 1641               -1.969652             1.286880          -0.141414
# 5261               -2.231865             1.759682           0.262855
# 3434                1.791127            -0.680337          -0.545682
# ...                      ...                  ...                ...
# 469                 0.297958            -0.022437          -0.949951
# 575                -0.914248             1.534356          -0.545682
# 761                -0.320029            -0.033662           0.262855
# 6159                1.953911            -0.383486          -0.949951
# 5635                0.624939            -0.005490          -1.354220
#
#       DecisionRateDif   OddsDif
# 220          0.127751 -0.896699
# 2052         0.127751  0.601441
# 1641        -0.416150 -1.203524
# 5261         0.127751  0.377951
# 3434        -0.960052 -2.434613
# ...               ...       ...
# 469         -0.960052  0.273782
# 575         -0.452410  3.360975
# 761          0.127751  1.201834
# 6159        -1.503953  0.652579
# 5635        -1.322653  0.993496
#
# [5040 rows x 32 columns]

# %%
ufc_data.plot_feature_distributions(processed = True)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 15. Save

# %%
ufc_modeling_data = ufc_data

# %%
save_data(ufc_modeling_data)
# Out:
# ✅ UFCData object saved to: /home/mlioi/ufc-predictor/data/processed/ufc_data.pkl

# %%
save_ufc_datasets(ufc_modeling_data, project_root)
# Out:
# ✅ UFCData object saved to: dict_keys(['ufc_train.csv', 'ufc_test.csv', 'ufc_processed_train.csv', 'ufc_processed_test.csv'])

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
