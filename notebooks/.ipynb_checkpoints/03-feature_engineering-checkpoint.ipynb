# %% [markdown]
# # 🔹UFC Fight Predictor Feature Engineering

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 1. Import Libraries and Setup Environment

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root, 'src'))
from utils.helpers import *
from utils.io_model import *
from utils.ufc_data import UFCData

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 2. Load Data

# %%
# Define the path to the CSV file
file_path = os.path.join(project_root, 'data', 'processed', 'ufc_etl.csv')

# Load the CSV into a DataFrame
try:
    ufc_df = pd.read_csv(file_path)
    print_header(f"Data loaded succesfully", color='bright_green')
except Exception as e:
    print_header(f"Error loading data: {e}", color='bright_red')
# Out:
# ╔═══════════════════════════╗
# ║  Data loaded succesfully  ║
# ╚═══════════════════════════╝

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 3. Initialize UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data.summary()
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6541
# 🧪 Train/Test split  : 5232 / 1309
# 🧪 Total features     : 68
#
# 🔢 Numerical features : 63
# 🔠 Categorical features: 5
#     - Binary          : 2
#     - Multiclass      : 3
#
# 🏷 Label distribution (raw):
#    - Class 0: 3795 (58.0%)
#    - Class 1: 2746 (42.0%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std     min       max
# NumberOfRounds                 3.187    0.580    3.00     5.000
# BlueCurrentLoseStreak          0.502    0.798    0.00     5.000
# BlueCurrentWinStreak           0.959    1.391    0.00    12.000
# BlueDraws                      0.023    0.155    0.00     2.000
# BlueAvgSigStrLanded           19.800   18.830    0.00   154.000
# BlueAvgSigStrPct               0.453    0.105    0.00     1.000
# BlueAvgSubAtt                  0.500    0.634    0.00     8.400
# BlueAvgTDLanded                1.315    1.261    0.00    10.610
# BlueAvgTDPct                   0.324    0.224    0.00     1.000
# BlueLongestWinStreak           1.923    1.952    0.00    17.000
# BlueLosses                     1.854    2.156    0.00    16.000
# BlueTotalRoundsFought         11.834   13.828    0.00   111.000
# BlueTotalTitleBouts            0.245    1.068    0.00    16.000
# BlueWinsByDecisionMajority     0.016    0.127    0.00     1.000
# BlueWinsByDecisionSplit        0.276    0.592    0.00     5.000
# BlueWinsByDecisionUnanimous    1.093    1.615    0.00    11.000
# BlueWinsByKO                   1.064    1.730    0.00    20.000
# BlueWinsBySubmission           0.633    1.264    0.00    13.000
# BlueWinsByTKODoctorStoppage    0.021    0.146    0.00     2.000
# BlueWins                       3.140    3.724    0.00    31.000
# BlueHeightCms                177.925    9.139  152.40   210.820
# BlueReachCms                 182.310   11.000  147.32   213.360
# BlueWeightLbs                163.498   34.876  115.00   265.000
# RedCurrentLoseStreak           0.620    0.870    0.00     7.000
# RedCurrentWinStreak            1.123    1.781    0.00    18.000
# RedDraws                       0.032    0.191    0.00     2.000
# RedAvgSigStrLanded            21.121   19.175    0.00   141.000
# RedAvgSigStrPct                0.460    0.096    0.00     1.000
# RedAvgSubAtt                   0.536    0.684    0.00     8.400
# RedAvgTDLanded                 1.397    1.282    0.00    12.500
# RedAvgTDPct                    0.340    0.215    0.00     1.000
# RedLongestWinStreak            2.708    2.246    0.00    18.000
# RedLosses                      2.572    2.722    0.00    21.000
# RedTotalRoundsFought          17.496   18.025    0.00   448.000
# RedTotalTitleBouts             0.534    1.478    0.00    16.000
# RedWinsByDecisionMajority      0.028    0.166    0.00     2.000
# RedWinsByDecisionSplit         0.399    0.693    0.00     4.000
# RedWinsByDecisionUnanimous     1.624    1.962    0.00    11.000
# RedWinsByKO                    1.574    2.154    0.00    21.000
# RedWinsBySubmission            0.950    1.641    0.00    16.000
# RedWinsByTKODoctorStoppage     0.034    0.193    0.00     2.000
# RedWins                        4.658    4.513    0.00    33.000
# RedHeightCms                 177.830    9.195  152.40   210.820
# RedReachCms                  182.422   11.157  149.86   214.630
# RedWeightLbs                 163.835   34.984  115.00   265.000
# RedAge                        30.379    4.169   18.00    47.000
# BlueAge                       29.796    3.979   19.00    47.000
# LoseStreakDif                  0.058    1.021   -6.00     6.000
# WinStreakDif                  -0.163    1.888  -18.00     9.000
# LongestWinStreakDif           -0.785    2.055  -12.00    14.000
# WinDif                        -1.518    4.214  -27.00    23.000
# LossDif                        0.050    3.137  -20.00    14.000
# TotalRoundDif                 -5.662   18.229 -448.00    87.000
# TotalTitleBoutDif             -0.289    1.622  -16.00    14.000
# KODif                         -0.524    2.147  -21.00    14.000
# SubDif                        -0.317    1.876  -16.00    10.000
# HeightDif                      0.096    6.295  -22.86    30.480
# ReachDif                      -0.142    8.591 -160.02    30.480
# AgeDif                         0.117    5.204  -17.00    17.000
# SigStrDif                     -2.733   19.478 -118.00   128.222
# AvgSubAttDif                  -0.072    0.904   -8.40     7.800
# AvgTDDif                      -0.178    1.744  -11.00    10.000
# TotalFightTimeSecs           657.128  342.903    5.00  1500.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 4. Feature Engineering

# %% [markdown]
# ### Categorical Data

# %% [markdown]
# ### Stance
# - **Orthodox Stance:** A fighter in orthodox stance leads with their left foot and left hand, making it the natural stance for right-handed individuals.
# - **Southpaw Stance:** A fighter in southpaw stance leads with their right foot and right hand, making it the natural stance for left-handed individuals.
# - **Open Stance Matchup:** When one fighter is orthodox and the other is southpaw, it creates an "open stance" matchup. This differs from a "closed stance" where both fighters are in the same stance (e.g., both orthodox or both southpaw)
# - **Switch:** When a fighter switches from an orthodox to a southpaw stance or vice versa, it can disrupt their opponent's rhythm, causing them to miss or react incorrectly to strikes.

# %% [markdown]
# ### Feature Construction

# %%
# Finish Rate (Red & Blue):
RedFinishRate = (ufc_df['RedWinsByKO'] + ufc_df['RedWinsBySubmission'] + ufc_df['RedWinsByTKODoctorStoppage']) / ufc_df['RedWins'].replace(0, 1)
BlueFinishRate = (ufc_df['BlueWinsByKO'] + ufc_df['BlueWinsBySubmission'] + ufc_df['BlueWinsByTKODoctorStoppage']) / ufc_df['BlueWins'].replace(0, 1)
ufc_df['FinishRate'] = BlueFinishRate - RedFinishRate

# %%
#Win Ratio (Red & Blue)
RedWinRatio = ufc_df['RedWins'] / (ufc_df['RedWins'] + ufc_df['RedLosses']).replace(0, 1)
BlueWinRatio = ufc_df['BlueWins'] / (ufc_df['BlueWins'] + ufc_df['BlueLosses']).replace(0, 1)
ufc_df['WinRatio']= BlueWinRatio - RedWinRatio

# %%
# Experience per Age
RedExpPerAge = ufc_df['RedTotalRoundsFought'] / ufc_df['RedAge']
BlueExpPerAge = ufc_df['BlueTotalRoundsFought'] / ufc_df['BlueAge']
ufc_df['ExpPerAge'] = RedExpPerAge - BlueExpPerAge

# %%
# Reach Advantage Ratio
ufc_df['ReachAdvantageRatio'] = ufc_df['RedReachCms'] / ufc_df['BlueReachCms']

# %%
# Height/Reach Ratio
RedHeightReachRatio = ufc_df['RedHeightCms'] / ufc_df['RedReachCms']
BlueHeightReachRatio = ufc_df['BlueHeightCms'] / ufc_df['BlueReachCms']
ufc_df['HeightReachRatio']= BlueHeightReachRatio - RedHeightReachRatio

# %%
# Win By Decision
BlueWinsByDecision = ufc_df[['BlueWinsByDecisionMajority', 'BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous']].sum(axis=1)
RedWinsByDecision = ufc_df[['RedWinsByDecisionMajority', 'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous']].sum(axis=1)
ufc_df['WinsByDecision']=BlueWinsByDecision- RedWinsByDecision

# %%
# Decision Rate
BlueDecisionRate = BlueWinsByDecision / ufc_df['BlueWins'].replace(0, 1)  # Evitar división por cero
RedDecisionRate = RedWinsByDecision  / ufc_df['RedWins'].replace(0, 1)  # Evitar división por cero
ufc_df['DecisionRate']= BlueDecisionRate - RedDecisionRate

# %% [markdown]
# ## 5. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data.summary()
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6541
# 🧪 Train/Test split  : 5232 / 1309
# 🧪 Total features     : 75
#
# 🔢 Numerical features : 70
# 🔠 Categorical features: 5
#     - Binary          : 2
#     - Multiclass      : 3
#
# 🏷 Label distribution (raw):
#    - Class 0: 3795 (58.0%)
#    - Class 1: 2746 (42.0%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std      min       max
# NumberOfRounds                 3.187    0.580    3.000     5.000
# BlueCurrentLoseStreak          0.502    0.798    0.000     5.000
# BlueCurrentWinStreak           0.959    1.391    0.000    12.000
# BlueDraws                      0.023    0.155    0.000     2.000
# BlueAvgSigStrLanded           19.800   18.830    0.000   154.000
# BlueAvgSigStrPct               0.453    0.105    0.000     1.000
# BlueAvgSubAtt                  0.500    0.634    0.000     8.400
# BlueAvgTDLanded                1.315    1.261    0.000    10.610
# BlueAvgTDPct                   0.324    0.224    0.000     1.000
# BlueLongestWinStreak           1.923    1.952    0.000    17.000
# BlueLosses                     1.854    2.156    0.000    16.000
# BlueTotalRoundsFought         11.834   13.828    0.000   111.000
# BlueTotalTitleBouts            0.245    1.068    0.000    16.000
# BlueWinsByDecisionMajority     0.016    0.127    0.000     1.000
# BlueWinsByDecisionSplit        0.276    0.592    0.000     5.000
# BlueWinsByDecisionUnanimous    1.093    1.615    0.000    11.000
# BlueWinsByKO                   1.064    1.730    0.000    20.000
# BlueWinsBySubmission           0.633    1.264    0.000    13.000
# BlueWinsByTKODoctorStoppage    0.021    0.146    0.000     2.000
# BlueWins                       3.140    3.724    0.000    31.000
# BlueHeightCms                177.925    9.139  152.400   210.820
# BlueReachCms                 182.310   11.000  147.320   213.360
# BlueWeightLbs                163.498   34.876  115.000   265.000
# RedCurrentLoseStreak           0.620    0.870    0.000     7.000
# RedCurrentWinStreak            1.123    1.781    0.000    18.000
# RedDraws                       0.032    0.191    0.000     2.000
# RedAvgSigStrLanded            21.121   19.175    0.000   141.000
# RedAvgSigStrPct                0.460    0.096    0.000     1.000
# RedAvgSubAtt                   0.536    0.684    0.000     8.400
# RedAvgTDLanded                 1.397    1.282    0.000    12.500
# RedAvgTDPct                    0.340    0.215    0.000     1.000
# RedLongestWinStreak            2.708    2.246    0.000    18.000
# RedLosses                      2.572    2.722    0.000    21.000
# RedTotalRoundsFought          17.496   18.025    0.000   448.000
# RedTotalTitleBouts             0.534    1.478    0.000    16.000
# RedWinsByDecisionMajority      0.028    0.166    0.000     2.000
# RedWinsByDecisionSplit         0.399    0.693    0.000     4.000
# RedWinsByDecisionUnanimous     1.624    1.962    0.000    11.000
# RedWinsByKO                    1.574    2.154    0.000    21.000
# RedWinsBySubmission            0.950    1.641    0.000    16.000
# RedWinsByTKODoctorStoppage     0.034    0.193    0.000     2.000
# RedWins                        4.658    4.513    0.000    33.000
# RedHeightCms                 177.830    9.195  152.400   210.820
# RedReachCms                  182.422   11.157  149.860   214.630
# RedWeightLbs                 163.835   34.984  115.000   265.000
# RedAge                        30.379    4.169   18.000    47.000
# BlueAge                       29.796    3.979   19.000    47.000
# LoseStreakDif                  0.058    1.021   -6.000     6.000
# WinStreakDif                  -0.163    1.888  -18.000     9.000
# LongestWinStreakDif           -0.785    2.055  -12.000    14.000
# WinDif                        -1.518    4.214  -27.000    23.000
# LossDif                        0.050    3.137  -20.000    14.000
# TotalRoundDif                 -5.662   18.229 -448.000    87.000
# TotalTitleBoutDif             -0.289    1.622  -16.000    14.000
# KODif                         -0.524    2.147  -21.000    14.000
# SubDif                        -0.317    1.876  -16.000    10.000
# HeightDif                      0.096    6.295  -22.860    30.480
# ReachDif                      -0.142    8.591 -160.020    30.480
# AgeDif                         0.117    5.204  -17.000    17.000
# SigStrDif                     -2.733   19.478 -118.000   128.222
# AvgSubAttDif                  -0.072    0.904   -8.400     7.800
# AvgTDDif                      -0.178    1.744  -11.000    10.000
# TotalFightTimeSecs           657.128  342.903    5.000  1500.000
# FinishRate                    -0.078    0.485   -1.000     1.000
# WinRatio                      -0.100    0.362   -1.000     1.000
# ExpPerAge                      0.169    0.522   -2.470    13.176
# ReachAdvantageRatio            1.002    0.046    0.855     1.206
# HeightReachRatio               0.001    0.036   -0.127     0.160
# WinsByDecision                -0.666    2.481  -14.000    11.000
# DecisionRate                  -0.062    0.463   -1.000     1.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 6. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
ufc_data.plot_corr(processed = status)

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Dado lo siguiente:
# -  LoseStreakDif: BlueCurrentLoseStreak - RedCurrentLoseStreak
# -  WinStreakDif: BlueCurrentWinStreak - RedCurrentWinStreak
# -  LongestWinStreakDif: BlueLongestWinStreak - 'RedLongestWinStreak
# -  WinDif: BlueWins - RedWins
# -  LossDif: BlueLosses - RedLosses
# -  TotalRoundDif: BlueTotalRoundsFought - RedTotalRoundsFought
# -  TotalTitleBoutDif: BlueTotalTitleBouts - RedTotalTitleBouts
# -  KODif: BlueWinsByKO - RedWinsByKO
# -  SubDif: BlueWinsBySubmission - RedWinsBySubmission
# -  HeightDif: BlueHeightCms - RedHeightCms
# -  ReachDif: BlueReachCms - RedReachCms
# -  AgeDif: BlueAge - RedAge
#
# Se eliminan ciertas columnas que pueden ser redundantes.

# %%
ufc_df=ufc_df.drop(['BlueCurrentLoseStreak', 'RedCurrentLoseStreak','BlueCurrentWinStreak',
                      'RedCurrentWinStreak','BlueLongestWinStreak', 'RedLongestWinStreak', 'BlueWins',
                      'RedWins','BlueLosses','RedLosses', 'BlueTotalRoundsFought','RedTotalRoundsFought',
                      'BlueTotalTitleBouts', 'RedTotalTitleBouts', 'BlueWinsByKO', 'RedWinsByKO', 'BlueWinsBySubmission',
                      'RedWinsBySubmission','BlueHeightCms','RedHeightCms','BlueReachCms','RedReachCms',
                      'BlueAge', 'RedAge'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ufc_df=ufc_df.drop(['BlueCurrentLoseStreak', 'RedCurrentLoseStreak','BlueCurrentWinStreak',
#       2                       'RedCurrentWinStreak','BlueLongestWinStreak', 'RedLongestWinStreak', 'BlueWins',
#       3                       'RedWins','BlueLosses','RedLosses', 'BlueTotalRoundsFought','RedTotalRoundsFought',
#       4                       'BlueTotalTitleBouts', 'RedTotalTitleBouts', 'BlueWinsByKO', 'RedWinsByKO', 'BlueWinsBySubmission',
#       5                       'RedWinsBySubmission','BlueHeightCms','RedHeightCms','BlueReachCms','RedReachCms',
#       6                       'BlueAge', 'RedAge'], axis=1)
#
# File ~/anaconda3/envs/ufc_env/lib/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/anaconda3/envs/ufc_env/lib/python3.13/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/anaconda3/envs/ufc_env/lib/python3.13/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/anaconda3/envs/ufc_env/lib/python3.13/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['BlueCurrentLoseStreak', 'RedCurrentLoseStreak', 'BlueCurrentWinStreak', 'RedCurrentWinStreak', 'BlueLongestWinStreak', 'RedLongestWinStreak', 'BlueWins', 'RedWins', 'BlueLosses', 'RedLosses', 'BlueTotalRoundsFought', 'RedTotalRoundsFought', 'BlueTotalTitleBouts', 'RedTotalTitleBouts', 'BlueWinsByKO', 'RedWinsByKO', 'BlueWinsBySubmission', 'RedWinsBySubmission', 'BlueHeightCms', 'RedHeightCms', 'BlueReachCms', 'RedReachCms', 'BlueAge', 'RedAge'] not found in axis"

# %% [markdown]
# También aquellas relacionadas con los features construidos:
# - WinsByDecision
# - DecisionRate
# - FinishRate

# %%
ufc_df=ufc_df.drop(['BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous',
       'BlueWinsByTKODoctorStoppage', 'RedWinsByDecisionMajority',
       'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous',
       'RedWinsByTKODoctorStoppage','BlueWinsByDecisionMajority'], axis=1)

# %% [markdown]
# ### Low Variance columns
# - BlueDraws
# - RedDraws
# - BlueWeightLbs
# - RedWeightLbs
# - TitleBout_True

# %%
ufc_df = ufc_df.drop(['BlueDraws','RedDraws','BlueWeightLbs','RedWeightLbs'], axis=1)

# %%
# Preview the first few records
display(ufc_df.head())
display(ufc_df.columns)
# Out:
#    TitleBout Gender  NumberOfRounds  BlueAvgSigStrLanded  BlueAvgSigStrPct  \
# 0      False   MALE               5                 4.13              0.36
# 1      False   MALE               3                 7.36              0.56
# 2      False   MALE               3                 3.32              0.48
# 3      False   MALE               3                 5.50              0.47
# 4      False   MALE               3                 5.94              0.52
#
#    BlueAvgSubAtt  BlueAvgTDLanded  BlueAvgTDPct BlueStance  \
# 0            0.0             1.96          0.46   Southpaw
# 1            1.1             1.24          0.23   Orthodox
# 2            0.2             2.26          0.28   Orthodox
# 3            0.0             0.36          0.25   Orthodox
# 4            0.0             0.25          0.50   Orthodox
#
#    RedAvgSigStrLanded  ...  BetterRank  TotalFightTimeSecs  label  FinishRate  \
# 0                3.88  ...         Red               882.0      1    0.283333
# 1                4.67  ...     neither               696.0      0    0.293233
# 2                4.44  ...         Red               717.0      0    0.500000
# 3                2.82  ...     neither               824.0      1   -0.100000
# 4                6.51  ...     neither               900.0      1   -0.607143
#
#    WinRatio  ExpPerAge  ReachAdvantageRatio  HeightReachRatio  WinsByDecision  \
# 0 -0.035714   0.477778             0.947368         -0.065058              -4
# 1  0.042614   1.222222             1.000000          0.028571              -9
# 2  0.095238   0.077799             1.046154          0.028733              -2
# 3 -0.261905  -0.453704             1.013158          0.025803               2
# 4  0.222222   0.064516             1.014493          0.013872               2
#
#    DecisionRate
# 0     -0.283333
# 1     -0.293233
# 2     -0.500000
# 3      0.100000
# 4      0.607143
#
# [5 rows x 40 columns]
# Index(['TitleBout', 'Gender', 'NumberOfRounds', 'BlueAvgSigStrLanded',
#        'BlueAvgSigStrPct', 'BlueAvgSubAtt', 'BlueAvgTDLanded', 'BlueAvgTDPct',
#        'BlueStance', 'RedAvgSigStrLanded', 'RedAvgSigStrPct', 'RedAvgSubAtt',
#        'RedAvgTDLanded', 'RedAvgTDPct', 'RedStance', 'LoseStreakDif',
#        'WinStreakDif', 'LongestWinStreakDif', 'WinDif', 'LossDif',
#        'TotalRoundDif', 'TotalTitleBoutDif', 'KODif', 'SubDif', 'HeightDif',
#        'ReachDif', 'AgeDif', 'SigStrDif', 'AvgSubAttDif', 'AvgTDDif',
#        'BetterRank', 'TotalFightTimeSecs', 'label', 'FinishRate', 'WinRatio',
#        'ExpPerAge', 'ReachAdvantageRatio', 'HeightReachRatio',
#        'WinsByDecision', 'DecisionRate'],
#       dtype='object')

# %% [markdown]
# ## 7. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data.summary()
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6541
# 🧪 Train/Test split  : 5232 / 1309
# 🧪 Total features     : 39
#
# 🔢 Numerical features : 34
# 🔠 Categorical features: 5
#     - Binary          : 2
#     - Multiclass      : 3
#
# 🏷 Label distribution (raw):
#    - Class 0: 3795 (58.0%)
#    - Class 1: 2746 (42.0%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                         mean      std      min       max
# NumberOfRounds         3.187    0.580    3.000     5.000
# BlueAvgSigStrLanded   19.800   18.830    0.000   154.000
# BlueAvgSigStrPct       0.453    0.105    0.000     1.000
# BlueAvgSubAtt          0.500    0.634    0.000     8.400
# BlueAvgTDLanded        1.315    1.261    0.000    10.610
# BlueAvgTDPct           0.324    0.224    0.000     1.000
# RedAvgSigStrLanded    21.121   19.175    0.000   141.000
# RedAvgSigStrPct        0.460    0.096    0.000     1.000
# RedAvgSubAtt           0.536    0.684    0.000     8.400
# RedAvgTDLanded         1.397    1.282    0.000    12.500
# RedAvgTDPct            0.340    0.215    0.000     1.000
# LoseStreakDif          0.058    1.021   -6.000     6.000
# WinStreakDif          -0.163    1.888  -18.000     9.000
# LongestWinStreakDif   -0.785    2.055  -12.000    14.000
# WinDif                -1.518    4.214  -27.000    23.000
# LossDif                0.050    3.137  -20.000    14.000
# TotalRoundDif         -5.662   18.229 -448.000    87.000
# TotalTitleBoutDif     -0.289    1.622  -16.000    14.000
# KODif                 -0.524    2.147  -21.000    14.000
# SubDif                -0.317    1.876  -16.000    10.000
# HeightDif              0.096    6.295  -22.860    30.480
# ReachDif              -0.142    8.591 -160.020    30.480
# AgeDif                 0.117    5.204  -17.000    17.000
# SigStrDif             -2.733   19.478 -118.000   128.222
# AvgSubAttDif          -0.072    0.904   -8.400     7.800
# AvgTDDif              -0.178    1.744  -11.000    10.000
# TotalFightTimeSecs   657.128  342.903    5.000  1500.000
# FinishRate            -0.078    0.485   -1.000     1.000
# WinRatio              -0.100    0.362   -1.000     1.000
# ExpPerAge              0.169    0.522   -2.470    13.176
# ReachAdvantageRatio    1.002    0.046    0.855     1.206
# HeightReachRatio       0.001    0.036   -0.127     0.160
# WinsByDecision        -0.666    2.481  -14.000    11.000
# DecisionRate          -0.062    0.463   -1.000     1.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 8. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                         Feature 1                    Feature 2  Correlation
# 2274                TotalRoundDif                    ExpPerAge     0.980629
# 1308                BlueWeightLbs                 RedWeightLbs     0.966121
# 2345                     ReachDif          ReachAdvantageRatio     0.965241
# 711         BlueTotalRoundsFought                     BlueWins     0.935975
# 2037                 RedHeightCms                  RedReachCms     0.901024
# 1190                BlueHeightCms                 BlueReachCms     0.896678
# 1756         RedTotalRoundsFought                      RedWins     0.886062
# 2226                       WinDif                TotalRoundDif     0.868544
# 645                    BlueLosses        BlueTotalRoundsFought     0.853399
# 594          BlueLongestWinStreak                     BlueWins     0.850302
# 2239                       WinDif                    ExpPerAge     0.849347
# 1683          RedLongestWinStreak                      RedWins     0.813436
# 707         BlueTotalRoundsFought  BlueWinsByDecisionUnanimous     0.810771
# 2038                 RedHeightCms                 RedWeightLbs     0.808198
# 1191                BlueHeightCms                BlueWeightLbs     0.805938
# 1712                    RedLosses         RedTotalRoundsFought     0.805561
# 1213                BlueHeightCms                 RedWeightLbs     0.797215
# 1306                BlueWeightLbs                 RedHeightCms     0.795328
# 1239                 BlueReachCms                BlueWeightLbs     0.777406
# 2064                  RedReachCms                 RedWeightLbs     0.777040
# 933   BlueWinsByDecisionUnanimous                     BlueWins     0.776243
# 1261                 BlueReachCms                 RedWeightLbs     0.769448
# 1307                BlueWeightLbs                  RedReachCms     0.768163
# 1803           RedTotalTitleBouts            TotalTitleBoutDif     0.766310
# 1890   RedWinsByDecisionUnanimous                      RedWins     0.765732
# 1211                BlueHeightCms                 RedHeightCms     0.764227
# 986                  BlueWinsByKO                     BlueWins     0.757009
# 1752         RedTotalRoundsFought   RedWinsByDecisionUnanimous     0.756448
# 1965          RedWinsBySubmission                       SubDif     0.749667
# 1720                    RedLosses                      RedWins     0.746397
# 2277                TotalRoundDif               WinsByDecision     0.741877
# 1259                 BlueReachCms                 RedHeightCms     0.740604
# 1921                  RedWinsByKO                      RedWins     0.739587
# 1212                BlueHeightCms                  RedReachCms     0.739421
# 586          BlueLongestWinStreak        BlueTotalRoundsFought     0.738190
# 2407                    ExpPerAge               WinsByDecision     0.737463
# 653                    BlueLosses                     BlueWins     0.733368
# 2242                       WinDif               WinsByDecision     0.732486
# 1260                 BlueReachCms                  RedReachCms     0.719329
# 1403          RedCurrentWinStreak                 WinStreakDif     0.713853
# 1767         RedTotalRoundsFought                TotalRoundDif     0.709113
# 1585                 RedAvgSubAtt                 AvgSubAttDif     0.694582
# 1780         RedTotalRoundsFought                    ExpPerAge     0.680339
# 590          BlueLongestWinStreak  BlueWinsByDecisionUnanimous     0.675672
# 1934                  RedWinsByKO                        KODif     0.666728
# 2205          LongestWinStreakDif                       WinDif     0.660869
# 591          BlueLongestWinStreak                 BlueWinsByKO     0.660358
# 1675          RedLongestWinStreak         RedTotalRoundsFought     0.659522
# 708         BlueTotalRoundsFought                 BlueWinsByKO     0.657812
# 1626               RedAvgTDLanded                     AvgTDDif     0.655455

# %%
ufc_data.plot_corr(processed = status)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 9. Inicialize Modeling Data: Standarize Numerical Data & Encode Categorical Data

# %%
ufc_data.standardize()
ufc_data.encode()

# %% [markdown]
# ## 10. Check Modeling Correlation Matrix

# %%
status = True
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                         Feature 1                    Feature 2  Correlation
# 3180                TotalRoundDif                    ExpPerAge     0.980629
# 765                BetterRank_Red           BetterRank_neither     0.967431
# 2214                BlueWeightLbs                 RedWeightLbs     0.966121
# 3251                     ReachDif          ReachAdvantageRatio     0.965241
# 1617        BlueTotalRoundsFought                     BlueWins     0.935975
# 2943                 RedHeightCms                  RedReachCms     0.901024
# 2096                BlueHeightCms                 BlueReachCms     0.896678
# 2662         RedTotalRoundsFought                      RedWins     0.886062
# 3132                       WinDif                TotalRoundDif     0.868544
# 1551                   BlueLosses        BlueTotalRoundsFought     0.853399
# 1500         BlueLongestWinStreak                     BlueWins     0.850302
# 3145                       WinDif                    ExpPerAge     0.849347
# 471            RedStance_Orthodox           RedStance_Southpaw     0.846054
# 161           BlueStance_Orthodox          BlueStance_Southpaw     0.840822
# 2589          RedLongestWinStreak                      RedWins     0.813436
# 1613        BlueTotalRoundsFought  BlueWinsByDecisionUnanimous     0.810771
# 2944                 RedHeightCms                 RedWeightLbs     0.808198
# 2097                BlueHeightCms                BlueWeightLbs     0.805938
# 2618                    RedLosses         RedTotalRoundsFought     0.805561
# 2119                BlueHeightCms                 RedWeightLbs     0.797215
# 2212                BlueWeightLbs                 RedHeightCms     0.795328
# 2145                 BlueReachCms                BlueWeightLbs     0.777406
# 2970                  RedReachCms                 RedWeightLbs     0.777040
# 1839  BlueWinsByDecisionUnanimous                     BlueWins     0.776243
# 2167                 BlueReachCms                 RedWeightLbs     0.769448
# 2213                BlueWeightLbs                  RedReachCms     0.768163
# 2709           RedTotalTitleBouts            TotalTitleBoutDif     0.766310
# 2796   RedWinsByDecisionUnanimous                      RedWins     0.765732
# 2117                BlueHeightCms                 RedHeightCms     0.764227
# 1892                 BlueWinsByKO                     BlueWins     0.757009
# 2658         RedTotalRoundsFought   RedWinsByDecisionUnanimous     0.756448
# 2871          RedWinsBySubmission                       SubDif     0.749667
# 2626                    RedLosses                      RedWins     0.746397
# 3183                TotalRoundDif               WinsByDecision     0.741877
# 2165                 BlueReachCms                 RedHeightCms     0.740604
# 2827                  RedWinsByKO                      RedWins     0.739587
# 2118                BlueHeightCms                  RedReachCms     0.739421
# 1492         BlueLongestWinStreak        BlueTotalRoundsFought     0.738190
# 3313                    ExpPerAge               WinsByDecision     0.737463
# 1559                   BlueLosses                     BlueWins     0.733368
# 3148                       WinDif               WinsByDecision     0.732486
# 2166                 BlueReachCms                  RedReachCms     0.719329
# 2309          RedCurrentWinStreak                 WinStreakDif     0.713853
# 2673         RedTotalRoundsFought                TotalRoundDif     0.709113
# 2491                 RedAvgSubAtt                 AvgSubAttDif     0.694582
# 2686         RedTotalRoundsFought                    ExpPerAge     0.680339
# 1496         BlueLongestWinStreak  BlueWinsByDecisionUnanimous     0.675672
# 2840                  RedWinsByKO                        KODif     0.666728
# 3111          LongestWinStreakDif                       WinDif     0.660869
# 1497         BlueLongestWinStreak                 BlueWinsByKO     0.660358

# %%
ufc_data.plot_corr(processed = status, threshold = 0.6)

# %% [markdown]
# ## 11. Check Modeling Data

# %%
ufc_data._X_train_processed
# Out:
#       TitleBout  Gender_MALE  BlueStance_Orthodox  BlueStance_Southpaw  \
# 5014          0            1                    0                    1
# 3094          0            1                    0                    1
# 3760          0            1                    0                    1
# 3951          0            1                    1                    0
# 6431          0            1                    1                    0
# ...         ...          ...                  ...                  ...
# 3513          0            1                    1                    0
# 2366          0            1                    1                    0
# 2982          0            1                    0                    1
# 4536          0            0                    1                    0
# 1441          0            1                    0                    1
#
#       BlueStance_Switch  RedStance_Open Stance  RedStance_Orthodox  \
# 5014                  0                      0                   0
# 3094                  0                      0                   1
# 3760                  0                      0                   1
# 3951                  0                      0                   1
# 6431                  0                      0                   0
# ...                 ...                    ...                 ...
# 3513                  0                      0                   1
# 2366                  0                      0                   1
# 2982                  0                      0                   1
# 4536                  0                      0                   1
# 1441                  0                      0                   1
#
#       RedStance_Southpaw  RedStance_Switch  BetterRank_Blue  ...  \
# 5014                   1                 0                0  ...
# 3094                   0                 0                0  ...
# 3760                   0                 0                0  ...
# 3951                   0                 0                0  ...
# 6431                   1                 0                0  ...
# ...                  ...               ...              ...  ...
# 3513                   0                 0                0  ...
# 2366                   0                 0                0  ...
# 2982                   0                 0                0  ...
# 4536                   0                 0                0  ...
# 1441                   0                 0                0  ...
#
#       AvgSubAttDif  AvgTDDif  TotalFightTimeSecs  FinishRate  WinRatio  \
# 5014     -1.025880  0.102213            0.708351    0.161448  0.275168
# 3094      0.079948  0.102213           -1.000753    0.161448  0.275168
# 3760     -0.104394 -0.184490            2.458287   -0.755016 -0.415658
# 3951      0.448520  0.102213            0.708351   -0.525900  0.275168
# 6431     -1.394452  0.675620           -0.924923   -0.525900  0.275168
# ...            ...       ...                 ...         ...       ...
# 3513     -0.235987  0.347976            2.458287    0.092713  0.373858
# 2366     -1.799959 -0.677620            0.708351   -0.400928  0.543125
# 2982      0.102064 -0.207426           -1.432404   -1.728758  1.712087
# 4536     -1.578793 -3.338228            0.708351    0.161448 -1.106484
# 1441      1.738689  1.822434            0.708351   -0.457165  1.337978
#
#       ExpPerAge  ReachAdvantageRatio  HeightReachRatio  WinsByDecision  \
# 5014  -0.164815            -0.035200          0.369952        0.268586
# 3094  -0.323718            -0.035200          1.528038        0.268586
# 3760   0.941574             1.652897          2.497677       -0.940745
# 3951  -1.034251            -1.538300         -1.625058        0.671696
# 6431  -0.006187            -0.949586         -0.810404       -0.134524
# ...         ...                  ...               ...             ...
# 3513   0.502277            -0.316550         -0.745772       -0.537635
# 2366  -2.770739             0.819810          1.709242        2.687248
# 2982   2.823551            -0.344288         -0.025277        0.671696
# 4536   0.118286            -0.035200         -0.476341       -0.134524
# 1441   2.318756             1.532318          1.465679       -1.343855
#
#       DecisionRate
# 5014      0.133795
# 3094      0.133795
# 3760      1.094677
# 3951      0.854457
# 6431      0.854457
# ...            ...
# 3513      0.205861
# 2366      0.723427
# 2982      2.115615
# 4536     -2.028191
# 1441      0.782390
#
# [5232 rows x 82 columns]

# %%
ufc_data.plot_feature_distributions(processed = True)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 12. Save

# %%
ufc_modeling_data = ufc_data

# %%
save_data(ufc_modeling_data)
# Out:
# ✅ UFCData object saved to: /home/mlioi/ufc-predictor/data/processed/ufc_data.pkl

# %%
save_ufc_datasets(ufc_modeling_data, project_root)
# Out:
# ✅ UFCData object saved to: dict_keys(['ufc_train.csv', 'ufc_test.csv', 'ufc_processed_train.csv', 'ufc_processed_test.csv'])

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
