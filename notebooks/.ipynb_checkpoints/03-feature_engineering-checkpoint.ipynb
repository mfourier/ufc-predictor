# %% [markdown]
# # 🔹UFC Fight Predictor Feature Engineering

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 1. Import Libraries and Setup Environment

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Navigate to the project root
project_root = os.path.abspath(os.path.join(current_dir, '..'))

# Import from /src
sys.path.append(os.path.join(project_root))
from src.helpers import *
from src.io_model import *
from src.data import UFCData

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 2. Load Data

# %%
# Define the path to the CSV file
file_path = os.path.join(project_root, 'data', 'processed', 'ufc_etl.csv')

# Load the CSV into a DataFrame
try:
    ufc_df = pd.read_csv(file_path)
    print_header(f"Data loaded succesfully", color='bright_green')
except Exception as e:
    print_header(f"Error loading data: {e}", color='bright_red')
# Out:
# ╔═══════════════════════════╗
# ║  Data loaded succesfully  ║
# ╚═══════════════════════════╝

# %% [markdown]
# ### Initial Drop for Modeling

# %%
ufc_df = ufc_df.drop(['RedFighter','BlueFighter','RedExpectedValue', 'Finish',
                      'BlueExpectedValue','Date','Location','Country', 'BetterRank'],axis=1)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 3. Initialize UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6057
# 🧪 Train/Test split  : 4845 / 1212
# 🧪 Total features     : 60
#
# 🔢 Numerical features : 54
# 🔠 Categorical features: 6
#     - Binary          : 3
#     - Multiclass      : 3
#
# 🏷 Label distribution (raw):
#    - Class 0: 3515 (58.0%)
#    - Class 1: 2542 (42.0%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std       min       max
# RedOdds                     -117.473  281.360 -2100.000   775.000
# BlueOdds                      61.305  255.318 -1200.000  1300.000
# NumberOfRounds                 3.192    0.587     3.000     5.000
# BlueCurrentLoseStreak          0.497    0.792     0.000     6.000
# BlueCurrentWinStreak           0.984    1.421     0.000    12.000
# BlueDraws                      0.022    0.150     0.000     2.000
# BlueLongestWinStreak           1.944    1.916     0.000    17.000
# BlueLosses                     1.878    2.180     0.000    16.000
# BlueTotalRoundsFought         11.973   13.777     0.000   111.000
# BlueTotalTitleBouts            0.243    1.018     0.000    13.000
# BlueWinsByDecisionMajority     0.016    0.127     0.000     2.000
# BlueWinsByDecisionSplit        0.282    0.601     0.000     5.000
# BlueWinsByDecisionUnanimous    1.114    1.613     0.000    11.000
# BlueWinsByKO                   1.083    1.718     0.000    20.000
# BlueWinsBySubmission           0.617    1.237     0.000    13.000
# BlueWinsByTKODoctorStoppage    0.025    0.163     0.000     2.000
# BlueWins                       3.178    3.682     0.000    31.000
# BlueHeightCms                177.780    9.118   152.400   210.820
# BlueReachCms                 182.147   10.940   147.320   213.360
# BlueWeightLbs                163.190   34.525   115.000   265.000
# RedCurrentLoseStreak           0.618    0.869     0.000     7.000
# RedCurrentWinStreak            1.132    1.784     0.000    18.000
# RedDraws                       0.030    0.185     0.000     2.000
# RedLongestWinStreak            2.734    2.256     0.000    18.000
# RedLosses                      2.584    2.689     0.000    20.000
# RedTotalRoundsFought          17.653   18.124     0.000   448.000
# RedTotalTitleBouts             0.565    1.561     0.000    16.000
# RedWinsByDecisionMajority      0.028    0.165     0.000     2.000
# RedWinsByDecisionSplit         0.408    0.708     0.000     5.000
# RedWinsByDecisionUnanimous     1.630    1.979     0.000    11.000
# RedWinsByKO                    1.601    2.162     0.000    21.000
# RedWinsBySubmission            0.944    1.620     0.000    16.000
# RedWinsByTKODoctorStoppage     0.036    0.201     0.000     2.000
# RedWins                        4.701    4.515     0.000    33.000
# RedHeightCms                 177.768    9.145   152.400   210.820
# RedReachCms                  182.382   11.090   147.320   214.630
# RedWeightLbs                 163.600   34.728   115.000   265.000
# RedAge                        30.376    4.174    18.000    47.000
# BlueAge                       29.765    3.931    20.000    46.000
# LoseStreakDif                  0.068    1.020    -5.000     6.000
# WinStreakDif                  -0.147    1.918   -18.000    10.000
# LongestWinStreakDif           -0.790    2.019   -12.000    14.000
# WinDif                        -1.524    4.226   -28.000    23.000
# LossDif                        0.081    3.148   -19.000    14.000
# TotalRoundDif                 -5.680   18.354  -448.000    87.000
# TotalTitleBoutDif             -0.322    1.655   -16.000    13.000
# KODif                         -0.529    2.157   -21.000    14.000
# SubDif                        -0.327    1.854   -16.000    10.000
# HeightDif                     -0.023    6.906  -187.960    30.480
# ReachDif                      -0.339    9.405  -187.960    30.480
# AgeDif                         0.133    5.172   -16.000    16.000
# SigStrDif                     -2.539   19.751  -118.000   128.222
# AvgSubAttDif                  -0.081    0.881    -8.300     7.800
# AvgTDDif                      -0.166    1.767   -10.333    10.860
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 4. Feature Engineering

# %% [markdown]
# ### Categorical Data

# %% [markdown]
# #### Stance
# - **Orthodox Stance:** A fighter in orthodox stance leads with their left foot and left hand, making it the natural stance for right-handed individuals.
# - **Southpaw Stance:** A fighter in southpaw stance leads with their right foot and right hand, making it the natural stance for left-handed individuals.
# - **Switch:** When a fighter switches from an orthodox to a southpaw stance or vice versa, it can disrupt their opponent's rhythm, causing them to miss or react incorrectly to strikes.
#
# This features are codified in Fight Stance Column via Closed and Open Stances Matchups

# %% [markdown]
# ###  Weight Class

# %%
ufc_df['WeightClass'].unique()
# Out:
# array(['Welterweight', 'Featherweight', 'Flyweight', 'Light Heavyweight',
#        'Bantamweight', 'Lightweight', "Women's Flyweight",
#        "Women's Strawweight", 'Heavyweight', 'Catch Weight',
#        'Middleweight', "Women's Bantamweight", "Women's Featherweight"],
#       dtype=object)

# %%
ufc_df[ufc_df['WeightClass'] == 'Catch Weight']
# Out:
#       RedOdds  BlueOdds  TitleBout   WeightClass Gender  NumberOfRounds  \
# 22     -112.0    -108.0      False  Catch Weight   MALE               3
# 43    -1000.0     650.0      False  Catch Weight   MALE               3
# 68      215.0    -265.0      False  Catch Weight   MALE               3
# 195     240.0    -298.0      False  Catch Weight   MALE               3
# 419    -115.0    -105.0      False  Catch Weight   MALE               3
# 424    -160.0     195.0      False  Catch Weight   MALE               3
# 476     300.0    -380.0      False  Catch Weight   MALE               3
# 512    -380.0     300.0      False  Catch Weight   MALE               5
# 608     116.0    -136.0      False  Catch Weight   MALE               3
# 625    -156.0     130.0      False  Catch Weight   MALE               3
# 649     110.0     138.0      False  Catch Weight   MALE               3
# 683    -390.0     310.0      False  Catch Weight   MALE               3
# 711    -168.0     142.0      False  Catch Weight   MALE               3
# 739     145.0    -170.0      False  Catch Weight   MALE               3
# 812    -155.0     135.0      False  Catch Weight   MALE               3
# 908    -180.0     155.0      False  Catch Weight   MALE               3
# 912    -125.0     105.0      False  Catch Weight   MALE               3
# 928    -580.0     440.0      False  Catch Weight   MALE               3
# 929     145.0    -170.0      False  Catch Weight   MALE               3
# 930    -195.0     165.0      False  Catch Weight   MALE               3
# 933    -645.0     480.0      False  Catch Weight   MALE               3
# 968     275.0    -330.0      False  Catch Weight   MALE               3
# 973     250.0    -300.0      False  Catch Weight   MALE               3
# 1143    180.0    -220.0      False  Catch Weight   MALE               3
# 1211   -190.0     160.0      False  Catch Weight   MALE               3
# 1223   -760.0     525.0      False  Catch Weight   MALE               5
# 1234   -335.0     260.0      False  Catch Weight   MALE               3
# 1450    170.0    -200.0      False  Catch Weight   MALE               3
# 1732    112.0    -129.0      False  Catch Weight   MALE               3
# 1750    390.0    -560.0      False  Catch Weight   MALE               3
# 1783    160.0    -185.0      False  Catch Weight   MALE               3
# 1787   -345.0     285.0      False  Catch Weight   MALE               3
# 1814   -155.0     125.0      False  Catch Weight   MALE               3
# 1830   -118.0    -106.0      False  Catch Weight   MALE               3
# 1864    140.0    -177.0      False  Catch Weight   MALE               3
# 1934    306.0    -420.0      False  Catch Weight   MALE               3
# 1962   -560.0     387.0      False  Catch Weight   MALE               3
# 2001   -250.0     195.0      False  Catch Weight   MALE               3
# 2036   -455.0     325.0      False  Catch Weight   MALE               3
# 2044    200.0    -240.0      False  Catch Weight   MALE               3
# 2058   -800.0     635.0      False  Catch Weight   MALE               3
# 2073    185.0    -225.0      False  Catch Weight   MALE               3
# 2076   -130.0     110.0      False  Catch Weight   MALE               3
# 2365   -170.0     150.0      False  Catch Weight   MALE               3
# 3189   -640.0     470.0      False  Catch Weight   MALE               3
# 3306    110.0    -130.0      False  Catch Weight   MALE               3
# 3458   -150.0     130.0      False  Catch Weight   MALE               3
# 3636    135.0    -155.0      False  Catch Weight   MALE               3
# 3644   -135.0     115.0      False  Catch Weight   MALE               3
# 3879  -1000.0     650.0      False  Catch Weight   MALE               3
# 3936   -450.0     360.0      False  Catch Weight   MALE               3
# 4293   -110.0    -110.0      False  Catch Weight   MALE               3
# 4590   -950.0     625.0      False  Catch Weight   MALE               3
# 4652    210.0    -230.0      False  Catch Weight   MALE               3
# 5334    310.0    -340.0      False  Catch Weight   MALE               3
# 5396    125.0    -135.0      False  Catch Weight   MALE               5
#
#       BlueCurrentLoseStreak  BlueCurrentWinStreak  BlueDraws  \
# 22                        0                     1          0
# 43                        2                     0          0
# 68                        0                     2          0
# 195                       0                     3          0
# 419                       0                     2          0
# 424                       0                     1          0
# 476                       0                     0          0
# 512                       0                     1          0
# 608                       0                     1          0
# 625                       1                     0          0
# 649                       0                     0          0
# 683                       0                     1          0
# 711                       0                     2          0
# 739                       0                     2          0
# 812                       0                     4          0
# 908                       1                     0          0
# 912                       0                     0          0
# 928                       0                     2          0
# 929                       0                     3          0
# 930                       0                     1          0
# 933                       0                     1          0
# 968                       0                     2          0
# 973                       0                     0          0
# 1143                      1                     0          0
# 1211                      0                     2          0
# 1223                      0                     2          1
# 1234                      0                     2          0
# 1450                      0                     1          1
# 1732                      0                     3          1
# 1750                      0                     3          0
# 1783                      2                     0          0
# 1787                      2                     0          0
# 1814                      0                     1          0
# 1830                      0                     2          0
# 1864                      0                     2          0
# 1934                      0                     1          0
# 1962                      0                     0          0
# 2001                      1                     0          0
# 2036                      4                     0          0
# 2044                      0                     2          0
# 2058                      0                     0          0
# 2073                      0                     1          0
# 2076                      0                     1          0
# 2365                      0                     1          0
# 3189                      0                     0          0
# 3306                      0                     1          0
# 3458                      0                     1          0
# 3636                      1                     0          0
# 3644                      0                     1          0
# 3879                      0                     0          0
# 3936                      0                     0          0
# 4293                      0                     0          0
# 4590                      0                     0          0
# 4652                      0                     0          0
# 5334                      0                     0          0
# 5396                      1                     0          0
#
#       BlueLongestWinStreak  ...  KODif  SubDif  HeightDif  ReachDif  AgeDif  \
# 22                       2  ...      0      -3      -2.54     -7.62      -3
# 43                       1  ...     -2       0       2.54     -5.08      -3
# 68                       2  ...     -1      -1       7.62     20.32      -5
# 195                      3  ...     -2      -1      10.16      2.54      -3
# 419                      3  ...     -1       3       7.62      5.08       5
# 424                      1  ...     -1       1       5.08      2.54       6
# 476                      0  ...      0       0       0.00     -5.08     -13
# 512                      4  ...      1       0      -7.62      2.54       5
# 608                      2  ...      0       1       0.00     -5.08       0
# 625                      2  ...      1       1       2.54     10.16       4
# 649                      0  ...      0       0       7.62      5.08      -2
# 683                      1  ...     -2      -1     -10.16     -7.62       8
# 711                      5  ...     -1      -1       5.08      5.08       0
# 739                      2  ...     -1      -1       5.08     -7.62       1
# 812                      4  ...     -3       1      -2.54     -2.54      -4
# 908                      0  ...     -1      -1       2.54    -10.16      -3
# 912                      0  ...      0      -1       2.54      5.08       2
# 928                      5  ...      2       1       2.54     15.24       1
# 929                      4  ...     -6       1       2.54      7.62       1
# 930                      3  ...      0       0       5.08     10.16      -3
# 933                      1  ...     -1      -2       2.54     -2.54      -5
# 968                      2  ...     -2       1      -2.54     -7.62      -9
# 973                      0  ...      0      -1       5.08      5.08      -6
# 1143                     2  ...     -1       0      -2.54     -7.62       2
# 1211                     3  ...     -4       1       7.62      5.08      -5
# 1223                     8  ...      1      -2       0.00      2.54       5
# 1234                     2  ...      1       0      -2.54     10.16       5
# 1450                     1  ...      0      -1     -10.16    -12.70      -7
# 1732                     3  ...      1       0       2.54    -20.32      -4
# 1750                     3  ...     -3      -2      -2.54     10.16     -10
# 1783                     2  ...      0       0      22.86      7.62       0
# 1787                     0  ...      0       0       0.00     10.16      -3
# 1814                     1  ...     -2      -1      10.16     12.70      -5
# 1830                     3  ...      1      -1      -2.54      2.54       5
# 1864                     2  ...      0      -2       2.54     -2.54       2
# 1934                     1  ...      2       0       7.62     10.16      -3
# 1962                     0  ...      0       0       2.54      7.62       0
# 2001                     2  ...      0      -2      -5.08     -5.08       7
# 2036                     1  ...      0       0      -2.54    -10.16      -2
# 2044                     2  ...     -3      -7      15.24      5.08     -10
# 2058                     0  ...      0       0      -2.54     -2.54       1
# 2073                     1  ...     -1      -1      -2.54      7.62      -6
# 2076                     1  ...      1      -1      -5.08      2.54      -4
# 2365                     1  ...      0      -3      -7.62     -7.62      -3
# 3189                     0  ...     -1       0       5.08      2.54       5
# 3306                     7  ...      1       1      -2.54     -2.54      -3
# 3458                     1  ...     -1       0       5.08      5.08      14
# 3636                     7  ...      5      -5       2.54     -2.54       0
# 3644                     1  ...      0       0      -5.08    -10.16       1
# 3879                     0  ...     -1      -1       0.00      0.00      -1
# 3936                     0  ...     -1       0      -5.08      0.00      -8
# 4293                     0  ...     -2       0      10.16      7.62       1
# 4590                     0  ...     -2      -1       0.00     10.16       1
# 4652                     0  ...      0       0       5.08      2.54       3
# 5334                     0  ...     -2      -2      -5.08     -7.62       6
# 5396                     7  ...      6       1       5.08      2.54      -2
#
#       SigStrDif  AvgSubAttDif  AvgTDDif    FightStance  label
# 22       0.2300       -0.7000   -1.6500    Open Stance      1
# 43       0.8700        0.0000    0.0000  Closed Stance      0
# 68      -1.2800       -0.4000    1.5200    Open Stance      0
# 195      0.5400        2.6000   -0.4900  Closed Stance      1
# 419     -1.5400        0.7000    0.1800    Open Stance      0
# 424      1.6800        2.1000    1.5100  Closed Stance      0
# 476      2.6800        0.0000    0.0000  Closed Stance      1
# 512      0.5100        0.0000   -0.3000    Open Stance      0
# 608     -3.2900        1.0000    2.7500  Closed Stance      1
# 625     -0.8100        0.2000   -1.6700  Closed Stance      1
# 649      2.7900        0.5000    0.2800  Closed Stance      1
# 683     -4.0800        0.4000    2.0400  Closed Stance      0
# 711     -1.1300        0.1000   -0.9500  Closed Stance      0
# 739      1.3700        0.3000   -0.8900    Open Stance      0
# 812      0.2200        0.4000   -0.2300  Closed Stance      0
# 908     -0.4100       -0.1000    0.1100    Open Stance      1
# 912      1.0400       -1.7000   -0.0200    Open Stance      1
# 928     -1.4700       -2.1000   -3.1500  Closed Stance      0
# 929      2.9600        0.1000   -0.6400    Open Stance      1
# 930     -1.4700        0.2000    2.2100  Closed Stance      0
# 933     -0.0100       -2.6000   -1.8700  Closed Stance      0
# 968     -1.3000        0.9000    2.1900  Closed Stance      0
# 973      1.4200       -0.9000   -6.5600  Closed Stance      1
# 1143     2.0200       -0.3000   -1.8800  Closed Stance      1
# 1211     0.9000        0.0000   -0.0600    Open Stance      0
# 1223     3.7800       -0.8000   -1.9600    Open Stance      0
# 1234    -0.5700       -1.8000   -0.8600    Open Stance      0
# 1450    -0.4800       -0.3000   -1.4500    Open Stance      0
# 1732    -0.2700        0.2000    0.3000    Open Stance      1
# 1750     0.9800       -1.2000   -0.4100  Closed Stance      1
# 1783    -1.6600        0.3000   -3.5800  Closed Stance      0
# 1787     0.6200       -0.3000   -3.1100  Closed Stance      0
# 1814    -4.6000       -0.4000    0.6300    Open Stance      1
# 1830     1.9700       -2.0000   -0.2000  Closed Stance      1
# 1864    -1.2700       -0.5000   -0.5200    Open Stance      1
# 1934     1.5800        1.2000    0.4600  Closed Stance      1
# 1962     0.0000        0.0000    0.0000    Open Stance      1
# 2001     0.3200       -2.5000   -2.4500    Open Stance      0
# 2036    -1.0900        0.8000    0.8300    Open Stance      1
# 2044     0.2900       -0.8000    0.1400    Open Stance      0
# 2058    -3.8400        0.0000   -7.8000  Closed Stance      0
# 2073    -3.0400        4.8000    1.0500    Open Stance      1
# 2076     3.3500       -4.0000   -0.8000    Open Stance      0
# 2365     0.5600       -2.3000   -1.3100    Open Stance      1
# 3189   -68.5000        0.0000   -3.5000  Closed Stance      0
# 3306     6.6071       -0.7500   -0.7262  Closed Stance      0
# 3458    -4.5962        1.3462   -0.7115    Open Stance      1
# 3636     9.1083       -1.1583   -0.5750    Open Stance      0
# 3644    18.2500        1.1667   -0.1667  Closed Stance      1
# 3879   -32.5000       -0.5000   -5.8333    Open Stance      0
# 3936   -56.5000        0.0000   -2.0000  Closed Stance      0
# 4293   -51.7500        0.0000    0.0000  Closed Stance      0
# 4590   -62.1250       -0.2500    0.0000  Closed Stance      0
# 4652     0.0000        0.0000    0.0000  Closed Stance      0
# 5334   -14.7778       -0.3333   -0.5556    Open Stance      1
# 5396    17.7111        0.0111    0.5222    Open Stance      1
#
# [56 rows x 61 columns]

# %%
ufc_df = ufc_df[ufc_df['WeightClass'] != 'Catch Weight']

# %%
ufc_df['WeightClass'].unique()
# Out:
# array(['Welterweight', 'Featherweight', 'Flyweight', 'Light Heavyweight',
#        'Bantamweight', 'Lightweight', "Women's Flyweight",
#        "Women's Strawweight", 'Heavyweight', 'Middleweight',
#        "Women's Bantamweight", "Women's Featherweight"], dtype=object)

# %%
# Diccionario de mapeo de WeightClass → WeightGroup
weight_class_map = {
    'Flyweight': 'Light',
    'Bantamweight': 'Light',
    'Featherweight': 'Light',
    'Lightweight': 'Light',
    'Welterweight': 'Medium',
    'Middleweight': 'Medium',
    'Light Heavyweight': 'Heavy',
    'Heavyweight': 'Heavy',
    "Women's Flyweight": 'Women',
    "Women's Strawweight": 'Women',
    "Women's Bantamweight": 'Women',
    "Women's Featherweight": 'Women',
}
# Crear nueva columna con el grupo
ufc_df['WeightGroup'] = ufc_df['WeightClass'].map(weight_class_map)

# %%
ufc_df['WeightGroup']
# Out:
# 0       Medium
# 1        Light
# 2        Light
# 3        Heavy
# 4        Light
#          ...
# 6052     Light
# 6053    Medium
# 6054     Heavy
# 6055    Medium
# 6056     Heavy
# Name: WeightGroup, Length: 6001, dtype: object

# %%
ufc_df['WeightClass']
# Out:
# 0            Welterweight
# 1           Featherweight
# 2               Flyweight
# 3       Light Heavyweight
# 4            Bantamweight
#               ...
# 6052          Lightweight
# 6053         Welterweight
# 6054          Heavyweight
# 6055         Welterweight
# 6056    Light Heavyweight
# Name: WeightClass, Length: 6001, dtype: object

# %%
ufc_df=ufc_df.drop(['WeightClass'], axis=1)

# %% [markdown]
# ### Feature Construction

# %%
# HeighDif (Clean)
ufc_df['HeightDif'] = ufc_df['BlueHeightCms'] - ufc_df['RedHeightCms']

# %%
# ReachDif (Clean)
ufc_df['ReachDif'] = ufc_df['BlueReachCms'] - ufc_df['RedReachCms']

# %%
# Finish Rate (Red & Blue):
RedFinishRate = (ufc_df['RedWinsByKO'] + ufc_df['RedWinsBySubmission'] + ufc_df['RedWinsByTKODoctorStoppage']) / ufc_df['RedWins'].replace(0, 1)
BlueFinishRate = (ufc_df['BlueWinsByKO'] + ufc_df['BlueWinsBySubmission'] + ufc_df['BlueWinsByTKODoctorStoppage']) / ufc_df['BlueWins'].replace(0, 1)
ufc_df['FinishRateDif'] = BlueFinishRate - RedFinishRate

# %%
#Win Ratio (Red & Blue)
RedWinRatio = ufc_df['RedWins'] / (ufc_df['RedWins'] + ufc_df['RedLosses'] + ufc_df['RedDraws']).replace(0, 1)
BlueWinRatio = ufc_df['BlueWins'] / (ufc_df['BlueWins'] + ufc_df['BlueLosses'] + ufc_df['BlueDraws']).replace(0, 1)
ufc_df['WinRateDif']= BlueWinRatio - RedWinRatio

# %%
# Experience per Age
RedExpPerAge = ufc_df['RedTotalRoundsFought'] / ufc_df['RedAge']
BlueExpPerAge = ufc_df['BlueTotalRoundsFought'] / ufc_df['BlueAge']
ufc_df['ExpPerAgeDif'] = BlueExpPerAge - RedExpPerAge

# %%
# Height/Reach Ratio
RedHeightReachRatio = ufc_df['RedHeightCms'] / ufc_df['RedReachCms']
BlueHeightReachRatio = ufc_df['BlueHeightCms'] / ufc_df['BlueReachCms']
ufc_df['HeightReachRatioDif']= BlueHeightReachRatio - RedHeightReachRatio

# %%
# Win By Decision
BlueWinsByDecision = ufc_df[['BlueWinsByDecisionMajority', 'BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous']].sum(axis=1)
RedWinsByDecision = ufc_df[['RedWinsByDecisionMajority', 'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous']].sum(axis=1)
ufc_df['WinsByDecisionDif']=BlueWinsByDecision - RedWinsByDecision

# %%
# Decision Rate
BlueDecisionRate = BlueWinsByDecision / ufc_df['BlueWins'].replace(0, 1)  # Evitar división por cero
RedDecisionRate = RedWinsByDecision  / ufc_df['RedWins'].replace(0, 1)  # Evitar división por cero
ufc_df['DecisionRateDif']= BlueDecisionRate - RedDecisionRate

# %%
# IsFiveRoundFight
ufc_df['IsFiveRoundFight'] = ufc_df['NumberOfRounds'] == 5

# %%
# Odds Dif
ufc_df['OddsDif'] = ufc_df['BlueOdds'] - ufc_df['RedOdds']

# %% [markdown]
# ## 5. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6001
# 🧪 Train/Test split  : 4800 / 1201
# 🧪 Total features     : 68
#
# 🔢 Numerical features : 61
# 🔠 Categorical features: 7
#     - Binary          : 4
#     - Multiclass      : 3
#
# 🏷 Label distribution (raw):
#    - Class 0: 3484 (58.1%)
#    - Class 1: 2517 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                                 mean      std       min       max
# RedOdds                     -117.620  276.878 -2100.000   775.000
# BlueOdds                      62.135  252.956 -1200.000  1300.000
# NumberOfRounds                 3.195    0.591     3.000     5.000
# BlueCurrentLoseStreak          0.505    0.794     0.000     5.000
# BlueCurrentWinStreak           0.970    1.430     0.000    12.000
# BlueDraws                      0.021    0.150     0.000     2.000
# BlueLongestWinStreak           1.954    1.961     0.000    17.000
# BlueLosses                     1.882    2.172     0.000    16.000
# BlueTotalRoundsFought         12.030   13.899     0.000   111.000
# BlueTotalTitleBouts            0.260    1.111     0.000    16.000
# BlueWinsByDecisionMajority     0.018    0.131     0.000     1.000
# BlueWinsByDecisionSplit        0.284    0.599     0.000     5.000
# BlueWinsByDecisionUnanimous    1.118    1.641     0.000    11.000
# BlueWinsByKO                   1.076    1.726     0.000    20.000
# BlueWinsBySubmission           0.622    1.250     0.000    13.000
# BlueWinsByTKODoctorStoppage    0.024    0.158     0.000     2.000
# BlueWins                       3.189    3.721     0.000    31.000
# BlueHeightCms                177.835    9.026   152.400   210.820
# BlueReachCms                 182.257   10.813   147.320   213.360
# BlueWeightLbs                163.317   34.085   115.000   265.000
# RedCurrentLoseStreak           0.616    0.866     0.000     7.000
# RedCurrentWinStreak            1.132    1.802     0.000    18.000
# RedDraws                       0.031    0.188     0.000     2.000
# RedLongestWinStreak            2.726    2.248     0.000    18.000
# RedLosses                      2.589    2.700     0.000    19.000
# RedTotalRoundsFought          17.723   18.177     0.000   448.000
# RedTotalTitleBouts             0.572    1.574     0.000    16.000
# RedWinsByDecisionMajority      0.027    0.162     0.000     1.000
# RedWinsByDecisionSplit         0.403    0.707     0.000     5.000
# RedWinsByDecisionUnanimous     1.645    1.977     0.000    11.000
# RedWinsByKO                    1.600    2.200     0.000    21.000
# RedWinsBySubmission            0.956    1.642     0.000    16.000
# RedWinsByTKODoctorStoppage     0.037    0.205     0.000     2.000
# RedWins                        4.726    4.541     0.000    33.000
# RedHeightCms                 177.865    9.102   152.400   210.820
# RedReachCms                  182.517   11.073   147.320   214.630
# RedWeightLbs                 163.746   34.382   115.000   265.000
# RedAge                        30.395    4.166    18.000    47.000
# BlueAge                       29.783    3.945    19.000    47.000
# LoseStreakDif                  0.059    1.012    -6.000     6.000
# WinStreakDif                  -0.162    1.921   -18.000    10.000
# LongestWinStreakDif           -0.772    2.053   -12.000    14.000
# WinDif                        -1.537    4.213   -28.000    23.000
# LossDif                        0.105    3.123   -16.000    16.000
# TotalRoundDif                 -5.693   18.286  -448.000    87.000
# TotalTitleBoutDif             -0.313    1.709   -16.000    15.000
# KODif                         -0.536    2.181   -21.000    14.000
# SubDif                        -0.334    1.877   -15.000    10.000
# HeightDif                     -0.030    6.286   -33.020    30.480
# ReachDif                      -0.260    8.266   -33.020    30.480
# AgeDif                         0.196    5.213   -17.000    17.000
# SigStrDif                     -2.540   19.869  -118.000   128.222
# AvgSubAttDif                  -0.076    0.880    -8.400     7.800
# AvgTDDif                      -0.159    1.765   -11.000    10.860
# FinishRateDif                 -0.077    0.478    -1.000     1.000
# WinRateDif                    -0.094    0.359    -1.000     1.000
# ExpPerAgeDif                  -0.169    0.525   -13.176     2.133
# HeightReachRatioDif            0.001    0.035    -0.120     0.124
# WinsByDecisionDif             -0.655    2.498   -14.000    11.000
# DecisionRateDif               -0.053    0.463    -1.000     1.000
# OddsDif                      179.755  525.039 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 6. Feature Selection

# %% [markdown]
# Given the following:
# -  LoseStreakDif: BlueCurrentLoseStreak - RedCurrentLoseStreak
# -  WinStreakDif: BlueCurrentWinStreak - RedCurrentWinStreak
# -  LongestWinStreakDif: BlueLongestWinStreak - 'RedLongestWinStreak
# -  WinDif: BlueWins - RedWins
# -  LossDif: BlueLosses - RedLosses
# -  WinRatioDif = BlueWinRatio - RedWinRatio
# -  TotalTitleBoutDif: BlueTotalTitleBouts - RedTotalTitleBouts
# -  KODif: BlueWinsByKO - RedWinsByKO
# -  SubDif: BlueWinsBySubmission - RedWinsBySubmission
# -  HeightDif: BlueHeightCms - RedHeightCms
# -  ReachDif: BlueReachCms - RedReachCms
# -  AgeDif: BlueAge - RedAge
# -  Odds Dif: BlueOdds - RedOdds
# -  FightStance: Defined using BlueStance and RedStance
#
# We drop redundant columns.

# %%
ufc_df=ufc_df.drop(['BlueCurrentLoseStreak', 'RedCurrentLoseStreak','BlueCurrentWinStreak', 'WinDif', 'LossDif',
                      'RedCurrentWinStreak','BlueLongestWinStreak', 'RedLongestWinStreak', 'BlueWins',
                      'RedWins','BlueLosses','RedLosses', 'BlueTotalRoundsFought','RedTotalRoundsFought',
                      'BlueTotalTitleBouts', 'RedTotalTitleBouts', 'BlueWinsByKO', 'RedWinsByKO', 'BlueWinsBySubmission',
                      'RedWinsBySubmission','BlueHeightCms','RedHeightCms','BlueReachCms','RedReachCms',
                      'BlueAge', 'RedAge', 'BlueOdds','RedOdds', 'BlueStance', 'RedStance'], axis=1)

# %% [markdown]
# - DecisionRateDif
# - FinishRateDif

# %%
ufc_df=ufc_df.drop(['WinsByDecisionDif', 'BlueWinsByDecisionSplit', 'BlueWinsByDecisionUnanimous',
       'BlueWinsByTKODoctorStoppage', 'RedWinsByDecisionMajority',
       'RedWinsByDecisionSplit', 'RedWinsByDecisionUnanimous',
       'RedWinsByTKODoctorStoppage','BlueWinsByDecisionMajority'], axis=1)

# %% [markdown]
# ### Low Variance columns
# - BlueDraws
# - RedDraws
# - BlueWeightLbs
# - RedWeightLbs

# %%
ufc_df = ufc_df.drop(['BlueDraws','RedDraws','BlueWeightLbs','RedWeightLbs'], axis=1)

# %% [markdown]
# ## 7. Update UFCData object

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6001
# 🧪 Train/Test split  : 4800 / 1201
# 🧪 Total features     : 25
#
# 🔢 Numerical features : 20
# 🔠 Categorical features: 5
#     - Binary          : 4
#     - Multiclass      : 1
#
# 🏷 Label distribution (raw):
#    - Class 0: 3484 (58.1%)
#    - Class 1: 2517 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                         mean      std       min       max
# NumberOfRounds         3.195    0.591     3.000     5.000
# LoseStreakDif          0.059    1.012    -6.000     6.000
# WinStreakDif          -0.162    1.921   -18.000    10.000
# LongestWinStreakDif   -0.772    2.053   -12.000    14.000
# TotalRoundDif         -5.693   18.286  -448.000    87.000
# TotalTitleBoutDif     -0.313    1.709   -16.000    15.000
# KODif                 -0.536    2.181   -21.000    14.000
# SubDif                -0.334    1.877   -15.000    10.000
# HeightDif             -0.030    6.286   -33.020    30.480
# ReachDif              -0.260    8.266   -33.020    30.480
# AgeDif                 0.196    5.213   -17.000    17.000
# SigStrDif             -2.540   19.869  -118.000   128.222
# AvgSubAttDif          -0.076    0.880    -8.400     7.800
# AvgTDDif              -0.159    1.765   -11.000    10.860
# FinishRateDif         -0.077    0.478    -1.000     1.000
# WinRateDif            -0.094    0.359    -1.000     1.000
# ExpPerAgeDif          -0.169    0.525   -13.176     2.133
# HeightReachRatioDif    0.001    0.035    -0.120     0.124
# DecisionRateDif       -0.053    0.463    -1.000     1.000
# OddsDif              179.755  525.039 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 8. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#                Feature 1            Feature 2  Correlation
# 81         TotalRoundDif         ExpPerAgeDif     0.981193
# 142             ReachDif  HeightReachRatioDif     0.642091
# 124            HeightDif             ReachDif     0.623959
# 178        FinishRateDif      DecisionRateDif     0.544058
# 66   LongestWinStreakDif         ExpPerAgeDif     0.509420

# %%
ufc_data.plot_corr(processed = status)

# %% [markdown]
# ## 9. Redundant Column
# - TotalRoundDif: BlueTotalRoundsFought - RedTotalRoundsFought (better to use ExpPerAgeDif)
# - NumberOfRounds equivalent to isFiveRound

# %%
ufc_df = ufc_df.drop(['NumberOfRounds','TotalRoundDif'], axis=1)

# %%
# Preview the first few records
display(ufc_df.head())
display(ufc_df.columns)
# Out:
#    TitleBout Gender  LoseStreakDif  WinStreakDif  LongestWinStreakDif  \
# 0      False   MALE             -1             5                   -2
# 1      False   MALE              0             0                   -2
# 2      False   MALE             -1             4                    0
# 3      False   MALE              1             0                   -1
# 4      False   MALE              0             3                   -2
#
#    TotalTitleBoutDif  KODif  SubDif  HeightDif  ReachDif  ...    FightStance  \
# 0                 -4      4      -2      -2.54     10.16  ...    Open Stance
# 1                  0     -2      -1       5.08      0.00  ...  Closed Stance
# 2                  0      1       1      -2.54     -7.62  ...    Open Stance
# 3                  0      2      -1       2.54     -2.54  ...  Closed Stance
# 4                  0     -5       0       0.00     -2.54  ...  Closed Stance
#
#    label  WeightGroup  FinishRateDif WinRateDif  ExpPerAgeDif  \
# 0      1       Medium       0.283333  -0.035714     -0.477778
# 1      0        Light       0.293233   0.042614     -1.222222
# 2      0        Light       0.500000   0.095238     -0.077799
# 3      1        Heavy      -0.100000  -0.300000      0.453704
# 4      1        Light      -0.607143   0.222222     -0.064516
#
#   HeightReachRatioDif  DecisionRateDif  IsFiveRoundFight  OddsDif
# 0           -0.065058        -0.283333              True   -455.0
# 1            0.028571        -0.293233             False   -272.0
# 2            0.028733        -0.500000             False    705.0
# 3            0.025803         0.100000             False    610.0
# 4            0.013872         0.607143             False   -410.0
#
# [5 rows x 24 columns]
# Index(['TitleBout', 'Gender', 'LoseStreakDif', 'WinStreakDif',
#        'LongestWinStreakDif', 'TotalTitleBoutDif', 'KODif', 'SubDif',
#        'HeightDif', 'ReachDif', 'AgeDif', 'SigStrDif', 'AvgSubAttDif',
#        'AvgTDDif', 'FightStance', 'label', 'WeightGroup', 'FinishRateDif',
#        'WinRateDif', 'ExpPerAgeDif', 'HeightReachRatioDif', 'DecisionRateDif',
#        'IsFiveRoundFight', 'OddsDif'],
#       dtype='object')

# %% [markdown]
# ## 10. Update UFCData Object

# %% [markdown]
# **After training, checking the importances feature plot, we decide to drop some columns that performs several worse than a Random Noise.**
# - LongestWinStreakDif
# - TitleBout
# - Gender

# %%
ufc_df = ufc_df.drop(['TitleBout', 'LongestWinStreakDif', 'Gender'], axis=1)

# %%
ufc_data = UFCData(ufc_df)
ufc_data
# Out:
# 📊 UFC Dataset Summary
# ----------------------------------------
# 🧪 Total samples      : 6001
# 🧪 Train/Test split  : 4800 / 1201
# 🧪 Total features     : 20
#
# 🔢 Numerical features : 17
# 🔠 Categorical features: 3
#     - Binary          : 2
#     - Multiclass      : 1
#
# 🏷 Label distribution (raw):
#    - Class 0: 3484 (58.1%)
#    - Class 1: 2517 (41.9%)
#
# ✅ No missing values detected
#
# 📈 Feature summary statistics (train set):
#                         mean      std       min       max
# LoseStreakDif          0.059    1.012    -6.000     6.000
# WinStreakDif          -0.162    1.921   -18.000    10.000
# TotalTitleBoutDif     -0.313    1.709   -16.000    15.000
# KODif                 -0.536    2.181   -21.000    14.000
# SubDif                -0.334    1.877   -15.000    10.000
# HeightDif             -0.030    6.286   -33.020    30.480
# ReachDif              -0.260    8.266   -33.020    30.480
# AgeDif                 0.196    5.213   -17.000    17.000
# SigStrDif             -2.540   19.869  -118.000   128.222
# AvgSubAttDif          -0.076    0.880    -8.400     7.800
# AvgTDDif              -0.159    1.765   -11.000    10.860
# FinishRateDif         -0.077    0.478    -1.000     1.000
# WinRateDif            -0.094    0.359    -1.000     1.000
# ExpPerAgeDif          -0.169    0.525   -13.176     2.133
# HeightReachRatioDif    0.001    0.035    -0.120     0.124
# DecisionRateDif       -0.053    0.463    -1.000     1.000
# OddsDif              179.755  525.039 -1975.000  3200.000
#
# ⚙️ Preprocessing status:
#    - Standardized?    : ❌
#    - Encoded?         : ❌
#    - Correlation cached (raw)      : ❌
#    - Correlation cached (processed): ❌
# ----------------------------------------

# %% [markdown]
# ## 11. Noise-based feature selection

# %%
# apply = False
# ufc_data.add_random_feature(apply=apply)
# ufc_data

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 12. Check Correlation Matrix

# %%
status = False
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status)
# Out:
#          Feature 1            Feature 2  Correlation
# 88        ReachDif  HeightReachRatioDif     0.642091
# 70       HeightDif             ReachDif     0.623959
# 124  FinishRateDif      DecisionRateDif     0.544058

# %% [markdown]
# ## 13. Inicialize Modeling Data: Standarize Numerical Data & Encode Categorical Data

# %%
ufc_data.standardize()
ufc_data.encode()

# %% [markdown]
# ## 14. Check Modeling Correlation Matrix

# %%
status = True
ufc_data.compute_corr(processed = status)
ufc_data.top_corr(processed = status, threshold = 0.4)
# Out:
#              Feature 1            Feature 2  Correlation
# 205           ReachDif  HeightReachRatioDif     0.642091
# 187          HeightDif             ReachDif     0.623959
# 63   WeightGroup_Light   WeightGroup_Medium     0.568048
# 241      FinishRateDif      DecisionRateDif     0.544058
# 171              KODif         ExpPerAgeDif     0.472663

# %%
ufc_data.plot_corr(processed = status, threshold = 0.4)

# %% [markdown]
# ## 15. Check Modeling Data

# %%
ufc_data._X_train_processed
# Out:
#       IsFiveRoundFight  FightStance_Open Stance  WeightGroup_Heavy  \
# 1535                 0                        0                  0
# 1760                 0                        0                  0
# 394                  0                        0                  0
# 4715                 1                        0                  0
# 3123                 0                        1                  0
# ...                ...                      ...                ...
# 1215                 0                        0                  0
# 3228                 0                        0                  1
# 3238                 0                        0                  0
# 1734                 0                        0                  0
# 3019                 0                        0                  0
#
#       WeightGroup_Light  WeightGroup_Medium  WeightGroup_Women  LoseStreakDif  \
# 1535                  1                   0                  0      -0.058245
# 1760                  1                   0                  0       0.929654
# 394                   0                   1                  0      -0.058245
# 4715                  0                   1                  0      -0.058245
# 3123                  1                   0                  0      -1.046144
# ...                 ...                 ...                ...            ...
# 1215                  1                   0                  0       0.929654
# 3228                  0                   0                  0       0.929654
# 3238                  0                   0                  1       0.929654
# 1734                  1                   0                  0      -0.058245
# 3019                  1                   0                  0      -0.058245
#
#       WinStreakDif  TotalTitleBoutDif     KODif  ...    AgeDif  SigStrDif  \
# 1535      0.605158           0.182949  0.704641  ...  0.346097   0.147989
# 1760     -0.956819           0.182949  0.246027  ... -0.421319   0.065941
# 394      -1.477478           0.182949  0.246027  ...  0.921659   0.025169
# 4715      0.605158          -0.402098 -2.964271  ...  0.154243  -0.694743
# 3123      0.084499           0.182949  0.246027  ... -1.572444   3.148019
# ...            ...                ...       ...  ...       ...        ...
# 1215     -0.436160           0.182949  0.246027  ... -0.996882   0.199835
# 3228      1.125817           0.182949 -0.671201  ...  1.689075   0.278862
# 3238      0.084499           0.182949 -0.212587  ...  1.880929  -2.330222
# 1734      0.084499           0.182949  0.246027  ...  1.305367   0.127854
# 3019      0.084499           0.182949  0.246027  ... -1.764298  -0.451011
#
#       AvgSubAttDif  AvgTDDif  FinishRateDif  WinRateDif  ExpPerAgeDif  \
# 1535     -0.367927 -2.175756       0.580189   -0.201640      0.526419
# 1760      1.564369  0.350706       0.161866   -0.253214      0.273520
# 394       0.768717  0.316718       0.336167   -0.665811      2.418547
# 4715     -0.212434 -0.118559       0.012465    0.995432     -1.902990
# 3123      0.086731  0.090129       0.161866    0.262531      0.506407
# ...            ...       ...            ...         ...           ...
# 1215     -0.595256  1.817867       0.161866   -2.522494      0.222281
# 3228      0.370892  0.231747       0.580189    1.306915     -0.253890
# 3238     -0.481592 -0.098676      -1.232542   -1.129981     -0.439898
# 1734      0.086731  0.090129       0.161866    0.262531      0.322062
# 3019     -0.292113 -0.570773       1.207672   -0.897896     -0.476182
#
#       HeightReachRatioDif  DecisionRateDif   OddsDif
# 1535            -0.006285        -0.316891  0.472861
# 1760            -0.045157         0.115228 -0.883369
# 394              1.709294        -0.064822  0.838586
# 4715            -0.428359         0.269556  0.390954
# 3123            -0.840912         0.115228  0.457623
# ...                   ...              ...       ...
# 1215            -2.143205        -2.045369  0.486195
# 3228            -0.304888        -0.316891 -0.837654
# 3238            -0.870724        -0.604971  0.762394
# 1734            -0.033369         0.115228  1.381460
# 3019            -1.225191        -0.965071  0.968114
#
# [4800 rows x 23 columns]

# %%
ufc_data.plot_feature_distributions(processed = True)

# %% [markdown]
# <div style="text-align: center;">
#   🔹 <img src="../img/ufc_logo.png" width="50" /> 🔹
# </div>

# %% [markdown]
# ## 16. Save

# %%
ufc_modeling_data = ufc_data

# %%
save_data(ufc_modeling_data)
# Out:
# ✅ UFCData object saved to: /home/mlioi/ufc-predictor/data/processed/ufc_data.pkl

# %%
save_ufc_datasets(ufc_modeling_data, project_root)
# Out:
# ✅ UFCData object saved to: dict_keys(['ufc_train.csv', 'ufc_test.csv', 'ufc_processed_train.csv', 'ufc_processed_test.csv'])

# %% [markdown]
# <div style="text-align: center;">
#      <img src="../img/ufc_logo.png" width="800" />
# </div>
